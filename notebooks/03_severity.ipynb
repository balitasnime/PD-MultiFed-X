# %%
# ==========================================================
# COMPLETE CODE FROM START TO END
# SINGLE TASK: DEPRESSION LEVELS ONLY (4 CLASSES)
# MRI FEATURES ALREADY EXTRACTED
# LATE FUSION AFTER TRANSFORMER-BIGRU (PARALLEL BRANCHES)
#   -> Transformer and BiGRU run IN PARALLEL on clinical data
#   -> MRI/image features fused at the END via 3 vectors:
#        tr_ctx (Transformer attention context)
#        g_last (last BiGRU hidden state)
#        mri_ctx (MRI branch embedding)
# MULTI-SEED (5 seeds) - NO FOLD (patient-wise 70/15/15 split)
# T2 / T4 / T6 + OPTUNA
# CPU VERSION
# ==========================================================

import re
import json
import random
import gc
import warnings
from pathlib import Path
from functools import reduce
from contextlib import nullcontext

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    f1_score,
    balanced_accuracy_score,
    accuracy_score,
    precision_score,
    recall_score,
)

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, WeightedRandomSampler

import optuna
from optuna.samplers import TPESampler
from optuna.pruners import MedianPruner

warnings.filterwarnings("ignore")

try:
    from IPython.display import display
except Exception:
    def display(x):
        print(x)


# ==========================================================
# 0) CONFIG
# ==========================================================
OUT_DIR = Path("/kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold")
OUT_DIR.mkdir(parents=True, exist_ok=True)

HORIZONS = {
    "T2": {"months": [0, 12], "last_month": 12},
    "T4": {"months": [0, 12, 24, 36], "last_month": 36},
    "T6": {"months": [0, 12, 24, 36, 48, 60], "last_month": 60},
}

# ✅ Multi-seed, sans fold
SEEDS = [42, 43, 44, 45, 46]
BASE_SEED = 42

TRAIN_RATIO = 0.70
VAL_RATIO = 0.15
TEST_RATIO = 0.15
assert abs(TRAIN_RATIO + VAL_RATIO + TEST_RATIO - 1.0) < 1e-9

N_TRIALS = 20
GRAD_CLIP = 1.0
MRI_MISSING_FILL = -1.0
NUM_CLASSES = 4

CLASS_NAMES = [
    "Level0_Minimal(0-4)",
    "Level1_Mild(5-8)",
    "Level2_Moderate(9-11)",
    "Level3_Severe(12+)",
]

NUM_WORKERS = 0
PIN_MEMORY = False

device = torch.device("cpu")
print("device:", device)


# ==========================================================
# 1) SEED
# ==========================================================
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
    if hasattr(torch.backends, "cudnn"):
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False


set_seed(BASE_SEED)


def autocast_context():
    return nullcontext()


# ==========================================================
# 2) FILE HELPERS
# ==========================================================
def find_file(filename):
    base = Path("/kaggle/input")
    matches = list(base.rglob(filename))
    if not matches:
        raise FileNotFoundError(f"{filename} introuvable dans /kaggle/input")
    print(f"[FOUND] {filename} -> {matches[0]}")
    return matches[0]


def read_csv_robust(path):
    return pd.read_csv(
        path,
        encoding="latin1",
        sep=None,
        engine="python",
        on_bad_lines="skip"
    )


# ==========================================================
# 3) ROBUST MRI FILE DETECTION (identique à ton code)
# ==========================================================
def list_possible_mri_files():
    base = Path("/kaggle/input")
    files = []
    for ext in ["*.csv", "*.xlsx", "*.xls", "*.parquet"]:
        files.extend(list(base.rglob(ext)))

    print("===== POSSIBLE FILES IN /kaggle/input =====")
    for f in files:
        print(f)
    print("===========================================")
    return files


def read_table_flexible(fp, nrows=None):
    fp = Path(fp)
    suffix = fp.suffix.lower()

    if suffix == ".csv":
        if nrows is None:
            return pd.read_csv(fp)
        return pd.read_csv(fp, nrows=nrows)

    elif suffix in [".xlsx", ".xls"]:
        if nrows is None:
            return pd.read_excel(fp)
        return pd.read_excel(fp, nrows=nrows)

    elif suffix == ".parquet":
        df = pd.read_parquet(fp)
        if nrows is not None:
            return df.head(nrows)
        return df

    else:
        raise ValueError(f"Unsupported file type: {fp}")


def detect_patno_column(cols):
    cols_lower = [str(c).strip().lower() for c in cols]

    patno_candidates = [
        "patno", "patient_id", "patientid", "subject_id", "subjectid", "id"
    ]

    for c in cols_lower:
        if c in patno_candidates:
            return c

    for c in cols_lower:
        if "patno" in c or "patient" in c or "subject" in c:
            return c

    return None


def detect_feature_columns(cols):
    cols_lower = [str(c).strip().lower() for c in cols]

    feature_cols = []

    for c in cols_lower:
        if c.startswith("mri_feat") or c.startswith("feat") or c.startswith("feature"):
            feature_cols.append(c)

    if len(feature_cols) == 0:
        excluded_keywords = [
            "patno", "patient", "subject", "id",
            "available", "flag", "label", "target",
            "event", "month", "time", "visit"
        ]
        for c in cols_lower:
            if not any(k in c for k in excluded_keywords):
                feature_cols.append(c)

    return feature_cols


def find_mri_feature_file():
    files = list_possible_mri_files()
    valid_files = []

    for fp in files:
        try:
            df_head = read_table_flexible(fp, nrows=5)
            cols_original = [str(c).strip() for c in df_head.columns]

            patno_col = detect_patno_column(cols_original)
            feat_cols = detect_feature_columns(cols_original)

            if patno_col is not None and len(feat_cols) >= 32:
                valid_files.append((fp, patno_col, feat_cols, cols_original))
        except Exception:
            pass

    if len(valid_files) == 0:
        raise FileNotFoundError(
            "Aucun fichier MRI valide trouvé.\n"
            "Il faut un fichier avec une colonne patient (PATNO ou similaire)\n"
            "et beaucoup de colonnes features."
        )

    print("\n===== MRI CANDIDATES FOUND =====")
    for i, (fp, patno_col, feat_cols, cols_original) in enumerate(valid_files):
        print(f"[{i}] File: {fp}")
        print(f"    PATNO column: {patno_col}")
        print(f"    Number of feature columns: {len(feat_cols)}")
        print(f"    First 10 columns: {cols_original[:10]}")
    print("================================\n")

    chosen_fp, chosen_patno, chosen_feat_cols, _ = valid_files[0]
    print("[SELECTED MRI FILE] ->", chosen_fp)
    print("[PATNO COLUMN] ->", chosen_patno)
    print("[NB FEATURES] ->", len(chosen_feat_cols))

    return chosen_fp, chosen_patno, chosen_feat_cols


def load_preextracted_mri_features_auto():
    mri_fp, patno_col_detected, feat_cols_detected = find_mri_feature_file()

    mri_df = read_table_flexible(mri_fp, nrows=None)
    original_cols = [str(c).strip() for c in mri_df.columns]
    lower_to_original = {str(c).strip().lower(): str(c).strip() for c in original_cols}

    patno_col_real = lower_to_original[patno_col_detected]
    feat_cols_real = [lower_to_original[c] for c in feat_cols_detected if c in lower_to_original]

    mri_df = mri_df.copy()
    mri_df[patno_col_real] = pd.to_numeric(mri_df[patno_col_real], errors="coerce")
    mri_df = mri_df.dropna(subset=[patno_col_real]).copy()
    mri_df[patno_col_real] = mri_df[patno_col_real].astype(int)

    available_col = None
    for c in original_cols:
        cl = c.lower()
        if "available" in cl or "flag" in cl:
            available_col = c
            break

    if available_col is None:
        mri_df["__MRI_AVAILABLE__"] = 1
        available_col = "__MRI_AVAILABLE__"

    good_feat_cols = []
    for c in feat_cols_real:
        vals = pd.to_numeric(mri_df[c], errors="coerce")
        if vals.notna().sum() > 0:
            mri_df[c] = vals
            good_feat_cols.append(c)

    if len(good_feat_cols) == 0:
        raise ValueError("No usable MRI feature columns found after numeric conversion.")

    feat_dim = len(good_feat_cols)
    print("[FINAL MRI FEATURE DIM] ->", feat_dim)

    feat_dict = {}
    for _, row in mri_df.iterrows():
        patno = int(row[patno_col_real])
        available = float(row[available_col]) if pd.notna(row[available_col]) else 0.0

        if available > 0.5:
            feat = row[good_feat_cols].to_numpy(dtype=np.float32)
            feat = np.nan_to_num(feat, nan=0.0, posinf=0.0, neginf=0.0)
            feat_dict[patno] = {
                "feat": feat,
                "available": 1.0
            }
        else:
            feat_dict[patno] = {
                "feat": np.full(feat_dim, MRI_MISSING_FILL, dtype=np.float32),
                "available": 0.0
            }

    return feat_dict, good_feat_cols, feat_dim

# ==========================================================
# 4) MERGE HELPERS
# ==========================================================
KEYS = ["PATNO", "EVENT_ID"]
DATE_CANDIDATES = ["INFODT", "VISITDT", "DATE", "EXAMDATE", "TESTDATE"]

ADMIN_WORDS = [
    "REC_ID", "PAG_NAME", "ORIG_ENTRY", "LAST_UPDATE",
    "ENTRY", "UPDATE", "NUPSOURC", "PTCGBOTH",
    "INFODT", "VISITDT", "EXAMDATE", "TESTDATE", "DATE"
]

LEAKY_CONTAINS = [
    "ESS_TOTAL", "SCORE_GDS", "SCAUTOT", "RBDTOT",
    "NP1RTOT", "NP2PTOT", "NP3TOT", "NHY"
]

_FR_MONTH = {
    "janv": "Jan", "févr": "Feb", "fevr": "Feb", "mars": "Mar", "avr": "Apr",
    "mai": "May", "juin": "Jun", "juil": "Jul", "août": "Aug", "aout": "Aug",
    "sept": "Sep", "oct": "Oct", "nov": "Nov", "déc": "Dec", "dec": "Dec"
}


def norm_cols(df):
    df = df.copy()
    df.columns = [str(c).strip().upper() for c in df.columns]
    return df


def coerce_keys(df):
    df = df.copy()
    if "PATNO" in df.columns:
        df["PATNO"] = pd.to_numeric(df["PATNO"], errors="coerce").astype("Int64")
    if "EVENT_ID" in df.columns:
        df["EVENT_ID"] = df["EVENT_ID"].astype(str).str.upper().str.strip()
    return df


def detect_date_col(df):
    for c in DATE_CANDIDATES:
        if c in df.columns:
            return c
    return None


def parse_date_series(s):
    s = s.astype(str).str.strip()
    for fr, en in _FR_MONTH.items():
        s = s.str.replace(fr, en, regex=False)
    return pd.to_datetime(s, errors="coerce", dayfirst=True)


def dedup_by_key_keep_latest(df, keys=None):
    df = df.copy()

    if keys is None:
        keys = [k for k in ["PATNO", "EVENT_ID"] if k in df.columns]

    if len(keys) == 0:
        return df.drop_duplicates(keep="last")

    dcol = detect_date_col(df)

    if dcol is not None:
        df["_DATE_TMP_"] = parse_date_series(df[dcol])
        df = df.sort_values(keys + ["_DATE_TMP_"])
        df = df.drop_duplicates(keys, keep="last")
        df = df.drop(columns=["_DATE_TMP_"])
    else:
        df = df.drop_duplicates(keys, keep="last")

    return df


def prefix_features(df, prefix, protected=("PATNO", "EVENT_ID")):
    df = df.copy()
    new_cols = {}
    for c in df.columns:
        if c not in protected:
            new_cols[c] = f"{prefix}{c}"
    return df.rename(columns=new_cols)


def event_id_to_month(x):
    x = str(x).strip().upper()
    if x == "BL":
        return 0
    m = re.fullmatch(r"V(\d+)", x)
    if m:
        v = int(m.group(1))
        return (v - 2) * 6
    return np.nan


def drop_admin_cols_safe(df):
    cols = []
    for c in df.columns:
        cu = c.upper()
        if cu in KEYS:
            continue
        if any(w in cu for w in ADMIN_WORDS):
            cols.append(c)
    return df.drop(columns=cols, errors="ignore")


def drop_leaky_cols_safe(df):
    cols = []
    for c in df.columns:
        cu = c.upper()
        if cu in KEYS:
            continue
        if any(w in cu for w in LEAKY_CONTAINS):
            cols.append(c)
    return df.drop(columns=cols, errors="ignore")


def filter_to_pd(participant_status):
    df = participant_status.copy()
    candidate_cols = [c for c in df.columns if "COHORT" in c or "STATUS" in c or "DEF" in c]

    if len(candidate_cols) == 0:
        txt = df.astype(str).agg(" ".join, axis=1)
    else:
        txt = pd.Series("", index=df.index)
        for c in candidate_cols:
            txt = txt.astype(str) + " " + df[c].astype(str)

    mask = txt.str.contains("PARKINSON", case=False, na=False)
    keep_pat = df.loc[mask, "PATNO"].dropna().astype(int).unique()
    return set(keep_pat)


def drop_low_variance_columns(df, cols, threshold=1e-8):
    keep = []
    for c in cols:
        vals = pd.to_numeric(df[c], errors="coerce")
        if vals.notna().sum() == 0:
            continue
        if vals.var(skipna=True) > threshold:
            keep.append(c)
    return keep


# ==========================================================
# 5) LOAD CLINICAL FILES
# ==========================================================
demo_path   = find_file("Demographics.csv")
ess_path    = find_file("Epworth_Sleepiness_Scale.csv")
up1_path    = find_file("MDS-UPDRS_Part_I.csv")
up4_path    = find_file("MDS-UPDRS_Part_IV.csv")
rem_path    = find_file("REM_Sleep_Behavior.csv")
scopa_path  = find_file("SCOPA-AUT.csv")
gds_path    = find_file("Geriatric_Depression_Scale.csv")
status_path = find_file("Participant_Status.csv")
up23_path   = find_file("UPDRS_PartII_PartIII.xlsx")

demo = prefix_features(
    dedup_by_key_keep_latest(coerce_keys(norm_cols(read_csv_robust(demo_path))), keys=["PATNO", "EVENT_ID"]),
    "DEMO__"
)
ess = prefix_features(
    dedup_by_key_keep_latest(coerce_keys(norm_cols(read_csv_robust(ess_path))), keys=["PATNO", "EVENT_ID"]),
    "ESS__"
)
up1 = prefix_features(
    dedup_by_key_keep_latest(coerce_keys(norm_cols(read_csv_robust(up1_path))), keys=["PATNO", "EVENT_ID"]),
    "UP1__"
)
up4 = prefix_features(
    dedup_by_key_keep_latest(coerce_keys(norm_cols(read_csv_robust(up4_path))), keys=["PATNO", "EVENT_ID"]),
    "UP4__"
)
rem = prefix_features(
    dedup_by_key_keep_latest(coerce_keys(norm_cols(read_csv_robust(rem_path))), keys=["PATNO", "EVENT_ID"]),
    "REM__"
)
scopa = prefix_features(
    dedup_by_key_keep_latest(coerce_keys(norm_cols(read_csv_robust(scopa_path))), keys=["PATNO", "EVENT_ID"]),
    "SCOPA__"
)
gds = prefix_features(
    dedup_by_key_keep_latest(coerce_keys(norm_cols(read_csv_robust(gds_path))), keys=["PATNO", "EVENT_ID"]),
    "GDS__"
)
status = dedup_by_key_keep_latest(coerce_keys(norm_cols(read_csv_robust(status_path))), keys=["PATNO"])

up23 = pd.read_excel(up23_path)
up23 = prefix_features(
    dedup_by_key_keep_latest(coerce_keys(norm_cols(up23)), keys=["PATNO", "EVENT_ID"]),
    "UP23__"
)

demo  = drop_leaky_cols_safe(drop_admin_cols_safe(demo))
ess   = drop_leaky_cols_safe(drop_admin_cols_safe(ess))
up1   = drop_leaky_cols_safe(drop_admin_cols_safe(up1))
up4   = drop_leaky_cols_safe(drop_admin_cols_safe(up4))
rem   = drop_leaky_cols_safe(drop_admin_cols_safe(rem))
scopa = drop_leaky_cols_safe(drop_admin_cols_safe(scopa))
gds   = drop_leaky_cols_safe(drop_admin_cols_safe(gds))
up23  = drop_leaky_cols_safe(drop_admin_cols_safe(up23))

dfs = [demo, ess, up1, up4, rem, scopa, gds, up23]
df_seq = reduce(lambda left, right: pd.merge(left, right, on=KEYS, how="outer"), dfs)

status = coerce_keys(norm_cols(status))
pd_patients = filter_to_pd(status)
df_seq = df_seq[df_seq["PATNO"].isin(pd_patients)].copy()

df_seq["MONTH"] = df_seq["EVENT_ID"].apply(event_id_to_month)
df_seq = df_seq[df_seq["MONTH"].notna()].copy()
df_seq["MONTH"] = df_seq["MONTH"].astype(int)

df_seq = df_seq.sort_values(["PATNO", "MONTH"])
df_seq = df_seq.drop_duplicates(subset=["PATNO", "MONTH"], keep="last").copy()

print("Merged df_seq shape:", df_seq.shape)


# ==========================================================
# 6) BUILD LEVELS LABEL ONLY (4 classes)
# ==========================================================
if "GDS__LEVELS" not in df_seq.columns:
    gds_score_candidates = [c for c in df_seq.columns if "GDS" in c and ("TOTAL" in c or "SCORE" in c)]
    if len(gds_score_candidates) == 0:
        raise ValueError("GDS__LEVELS not found and no GDS score column detected.")
    gds_score_col = gds_score_candidates[0]
    score = pd.to_numeric(df_seq[gds_score_col], errors="coerce")

    levels = pd.Series(np.nan, index=df_seq.index)
    levels[(score >= 0) & (score <= 4)] = 0
    levels[(score >= 5) & (score <= 8)] = 1
    levels[(score >= 9) & (score <= 11)] = 2
    levels[(score >= 12)] = 3
    df_seq["GDS__LEVELS"] = levels.astype("Float64")

print("Levels labels ready.")


# ==========================================================
# 7) KEEP NUMERIC CLINICAL FEATURES
# ==========================================================
protected_cols = ["PATNO", "EVENT_ID", "MONTH", "GDS__LEVELS"]

for c in df_seq.columns:
    if c not in ["PATNO", "EVENT_ID"]:
        df_seq[c] = pd.to_numeric(df_seq[c], errors="ignore")

numeric_cols = []
for c in df_seq.columns:
    if c in protected_cols:
        continue
    if pd.api.types.is_numeric_dtype(df_seq[c]):
        numeric_cols.append(c)

feature_cols_model = []
for c in numeric_cols:
    miss = df_seq[c].isna().mean()
    protected_prefix = c.startswith(("ESS__", "REM__", "SCOPA__", "GDS__", "UP1__", "UP4__", "UP23__", "DEMO__"))
    if miss <= 0.90 or protected_prefix:
        feature_cols_model.append(c)

feature_cols_model = drop_low_variance_columns(df_seq, feature_cols_model)
print("Clinical feature columns:", len(feature_cols_model))

CLINICAL_RAW_DIM = len(feature_cols_model)


# ==========================================================
# 8) LOAD MRI FEATURES AUTO
# ==========================================================
mri_feat_dict, MRI_FEATURE_COLUMNS, MRI_FEAT_DIM = load_preextracted_mri_features_auto()
FLAG_DIM = 1
print("✅ Clinical raw dim:", CLINICAL_RAW_DIM)
print("✅ MRI feature dim:", MRI_FEAT_DIM)

# ==========================================================
# 9) MAKE SEQUENCES - RAW FUSED LAYOUT
#    [clinical_raw | mri_raw | mri_flag] per time step.
#    The MODEL itself splits this layout and processes:
#      - clinical -> Transformer (parallel) + BiGRU (parallel)
#      - MRI (last time point) -> separate MRI branch
#    then fuses tr_ctx + g_last + mri_ctx at the very end.
# ==========================================================
def make_levels_sequences_raw_fused(df_seq, feature_cols, months, last_month):
    Xfused_list, pat_list = [], []
    y_list = []

    for patno, g in df_seq.groupby("PATNO"):
        g = g.copy()
        g = g.sort_values("MONTH")
        g = g.drop_duplicates(subset=["MONTH"], keep="last")
        g = g.set_index("MONTH")

        if last_month not in g.index:
            continue

        gg = g.reindex(months)
        Xc = gg[feature_cols].to_numpy(dtype=np.float32)

        row_last = g.loc[last_month]
        if isinstance(row_last, pd.DataFrame):
            row_last = row_last.iloc[-1]

        y_lvl = row_last["GDS__LEVELS"] if "GDS__LEVELS" in row_last.index else pd.NA
        if pd.isna(y_lvl):
            continue

        if int(patno) in mri_feat_dict:
            xmri = mri_feat_dict[int(patno)]["feat"].astype(np.float32)
            xflag = np.array([mri_feat_dict[int(patno)]["available"]], dtype=np.float32)
        else:
            xmri = np.full(MRI_FEAT_DIM, MRI_MISSING_FILL, dtype=np.float32)
            xflag = np.array([0.0], dtype=np.float32)

        T = Xc.shape[0]
        xmri_rep = np.repeat(xmri.reshape(1, -1), T, axis=0)
        xflag_rep = np.repeat(xflag.reshape(1, -1), T, axis=0)

        Xfused = np.concatenate([Xc, xmri_rep, xflag_rep], axis=1).astype(np.float32)

        Xfused_list.append(Xfused)
        pat_list.append(int(patno))
        y_list.append(int(y_lvl))

    if len(Xfused_list) == 0:
        raise ValueError("Aucune séquence construite.")

    return (
        np.stack(Xfused_list).astype(np.float32),
        np.array(y_list, dtype=np.int64),
        np.array(pat_list, dtype=np.int64),
    )


X2, y2, p2 = make_levels_sequences_raw_fused(df_seq, feature_cols_model, HORIZONS["T2"]["months"], HORIZONS["T2"]["last_month"])
X4, y4, p4 = make_levels_sequences_raw_fused(df_seq, feature_cols_model, HORIZONS["T4"]["months"], HORIZONS["T4"]["last_month"])
X6, y6, p6 = make_levels_sequences_raw_fused(df_seq, feature_cols_model, HORIZONS["T6"]["months"], HORIZONS["T6"]["last_month"])

print("✅ T2 fused:", X2.shape, "unique patients:", len(np.unique(p2)))
print("✅ T4 fused:", X4.shape, "unique patients:", len(np.unique(p4)))
print("✅ T6 fused:", X6.shape, "unique patients:", len(np.unique(p6)))


# ==========================================================
# 10) SPLIT PATIENT-WISE 70/15/15 (SANS FOLD)
# ==========================================================
def split_train_val_test_patientwise(X, y, pat, train_ratio=0.70, val_ratio=0.15, test_ratio=0.15, seed=42):
    assert abs(train_ratio + val_ratio + test_ratio - 1.0) < 1e-9

    unique_pat = np.unique(pat)

    gss1 = GroupShuffleSplit(n_splits=1, test_size=(val_ratio + test_ratio), random_state=seed)
    tr_pat_idx, tmp_pat_idx = next(gss1.split(unique_pat, groups=unique_pat))
    pat_tr_set = set(unique_pat[tr_pat_idx])
    pat_tmp = unique_pat[tmp_pat_idx]

    test_share_of_temp = test_ratio / (val_ratio + test_ratio)
    gss2 = GroupShuffleSplit(n_splits=1, test_size=test_share_of_temp, random_state=seed)
    va_pat_idx, te_pat_idx = next(gss2.split(pat_tmp, groups=pat_tmp))
    pat_va_set = set(pat_tmp[va_pat_idx])
    pat_te_set = set(pat_tmp[te_pat_idx])

    tr_idx = np.array([i for i, pp in enumerate(pat) if pp in pat_tr_set], dtype=int)
    va_idx = np.array([i for i, pp in enumerate(pat) if pp in pat_va_set], dtype=int)
    te_idx = np.array([i for i, pp in enumerate(pat) if pp in pat_te_set], dtype=int)

    return (
        (X[tr_idx], y[tr_idx], pat[tr_idx]),
        (X[va_idx], y[va_idx], pat[va_idx]),
        (X[te_idx], y[te_idx], pat[te_idx]),
    )


def print_split_info(name, tr, va, te):
    X_tr, y_tr, pat_tr = tr
    X_va, y_va, pat_va = va
    X_te, y_te, pat_te = te
    print(f"\n{name} SPLIT:")
    print("Train:", X_tr.shape, "patients:", len(np.unique(pat_tr)), "class:", np.unique(y_tr, return_counts=True))
    print("Val  :", X_va.shape, "patients:", len(np.unique(pat_va)), "class:", np.unique(y_va, return_counts=True))
    print("Test :", X_te.shape, "patients:", len(np.unique(pat_te)), "class:", np.unique(y_te, return_counts=True))


# ==========================================================
# 11) PREPROCESSING TRAIN ONLY + NaN MASK
#     Output layout: [scaled(clinical|mri|flag) | mask(clinical|mri|flag)]
#     -> matches exactly what the model's split function expects.
# ==========================================================
def fit_preprocess_train_only_with_mask(X_train):
    X_train = X_train.astype(np.float32)
    N, T, Fdim = X_train.shape

    mask = np.isfinite(X_train).astype(np.float32)

    flat = X_train.reshape(-1, Fdim)
    med = np.nanmedian(flat, axis=0)
    med = np.where(np.isfinite(med), med, 0.0)

    flat_imp = flat.copy()
    inds = np.where(~np.isfinite(flat_imp))
    flat_imp[inds] = np.take(med, inds[1])

    scaler = MinMaxScaler()
    flat_scaled = scaler.fit_transform(flat_imp)
    X_scaled = flat_scaled.reshape(N, T, Fdim).astype(np.float32)

    X_out = np.concatenate([X_scaled, mask], axis=-1).astype(np.float32)
    return X_out, med.astype(np.float32), scaler


def transform_with_train_params_with_mask(X, med, scaler):
    X = X.astype(np.float32)
    N, T, Fdim = X.shape

    mask = np.isfinite(X).astype(np.float32)

    flat = X.reshape(-1, Fdim)
    flat_imp = flat.copy()
    inds = np.where(~np.isfinite(flat_imp))
    flat_imp[inds] = np.take(med, inds[1])

    flat_scaled = scaler.transform(flat_imp)
    X_scaled = flat_scaled.reshape(N, T, Fdim).astype(np.float32)

    X_out = np.concatenate([X_scaled, mask], axis=-1).astype(np.float32)
    return X_out

# ==========================================================
# 12) LOSS (multiclass focal, avec poids inverse-fréquence)
# ==========================================================
def inverse_freq_weights(y, n_classes, power=1.0, max_w=8.0):
    y = np.asarray(y, dtype=np.int64)
    counts = np.bincount(y, minlength=n_classes).astype(np.float32)
    counts[counts == 0] = 1.0
    w = (counts.sum() / counts) ** power
    w = w / w.mean()
    w = np.clip(w, 1.0, max_w)
    return torch.tensor(w, dtype=torch.float32, device=device)


class FocalLossMulti(nn.Module):
    def __init__(self, gamma=2.0, weight=None, reduction="mean"):
        super().__init__()
        self.gamma = gamma
        self.weight = weight
        self.reduction = reduction

    def forward(self, logits, targets):
        ce = F.cross_entropy(logits, targets, weight=self.weight, reduction="none")
        pt = torch.exp(-ce)
        loss = ((1 - pt) ** self.gamma) * ce
        if self.reduction == "mean":
            return loss.mean()
        return loss.sum()


# ==========================================================
# 13) AUGMENTATION (numpy, appliquée une fois avant l'entraînement)
# ==========================================================
def augment_noise(X, scale=0.01):
    if scale <= 0:
        return X.astype(np.float32)
    noise = np.random.normal(0, scale, X.shape).astype(np.float32)
    return (X + noise).astype(np.float32)


def apply_input_dropout(X, p=0.05, fill_value=0.0):
    if p is None or p <= 0:
        return X.astype(np.float32)
    X = X.astype(np.float32, copy=True)
    mask = (np.random.rand(*X.shape) < p)
    X[mask] = np.float32(fill_value)
    return X


def make_sampler(y, n_classes):
    counts = np.bincount(y, minlength=n_classes).astype(np.float32)
    counts[counts == 0] = 1.0
    inv = 1.0 / counts
    sample_w = inv[np.clip(y, 0, n_classes - 1)]
    sample_w = torch.tensor(sample_w, dtype=torch.float32)
    return WeightedRandomSampler(sample_w, num_samples=len(sample_w), replacement=True)


# ==========================================================
# 14) MODEL: TRANSFORMER + BiGRU EN PARALLELE
#     LATE FUSION A 3 BRANCHES (tr_ctx, g_last, mri_ctx)
# ==========================================================
class LevelsParallelLateFusionModel(nn.Module):
    """
    Late fusion à 3 branches :
      1) Transformer (attention pooling)  -> tr_ctx
      2) BiGRU (dernier état caché)       -> g_last
         (Transformer et BiGRU reçoivent TOUS LES DEUX
          directement les données cliniques, EN PARALLELE,
          pas en série comme un Transformer->GRU classique)
      3) Branche MRI/image (dernier point temporel) -> mri_ctx
    Fusion finale : concat([tr_ctx, g_last, mri_ctx]) -> tête de classification (4 classes)

    Input layout après preprocessing :
      [scaled clinical | scaled MRI | scaled MRI_flag | mask clinical | mask MRI | mask MRI_flag]
    """
    def __init__(
        self,
        clinical_raw_dim,
        mri_feat_dim,
        flag_dim=1,
        max_len=6,
        d_model=128,
        nhead=4,
        num_layers=2,
        dim_feedforward=256,
        gru_hidden=64,
        gru_layers=1,
        head_hidden=128,
        dropout=0.30,
        num_classes=4,
    ):
        super().__init__()

        if d_model % nhead != 0:
            raise ValueError(f"d_model ({d_model}) must be divisible by nhead ({nhead})")

        self.clinical_raw_dim = int(clinical_raw_dim)
        self.mri_feat_dim = int(mri_feat_dim)
        self.flag_dim = int(flag_dim)
        self.raw_total_dim = self.clinical_raw_dim + self.mri_feat_dim + self.flag_dim

        clinical_input_dim = self.clinical_raw_dim * 2       # scaled + mask
        mri_fusion_dim = (self.mri_feat_dim + self.flag_dim) * 2  # scaled + mask

        # ---- Branche Transformer (clinique) ----
        self.input_proj = nn.Sequential(
            nn.Linear(clinical_input_dim, d_model),
            nn.LayerNorm(d_model),
            nn.GELU(),
            nn.Dropout(dropout)
        )
        self.pos = nn.Parameter(torch.randn(1, max_len, d_model) * 0.02)

        enc_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True,
            activation="gelu",
            norm_first=False
        )
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
        self.tr_norm = nn.LayerNorm(d_model)

        self.tr_attn = nn.Sequential(
            nn.Linear(d_model, d_model // 2),
            nn.Tanh(),
            nn.Dropout(dropout),
            nn.Linear(d_model // 2, 1)
        )

        # ---- Branche BiGRU (clinique, EN PARALLELE du Transformer) ----
        self.gru = nn.GRU(
            input_size=clinical_input_dim,
            hidden_size=gru_hidden,
            num_layers=gru_layers,
            batch_first=True,
            dropout=(dropout if gru_layers > 1 else 0.0),
            bidirectional=True
        )
        self.gru_norm = nn.LayerNorm(gru_hidden * 2)

        # ---- Branche MRI/image (dernier point temporel uniquement) ----
        self.mri_branch = nn.Sequential(
            nn.Linear(mri_fusion_dim, 128),
            nn.LayerNorm(128),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(128, 64),
            nn.GELU(),
        )

        # ---- Fusion finale (3 vecteurs) ----
        fusion_dim = d_model + (gru_hidden * 2) + 64
        self.head = nn.Sequential(
            nn.Linear(fusion_dim, head_hidden),
            nn.LayerNorm(head_hidden),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(head_hidden, num_classes)
        )

    def split_clinical_mri(self, x):
        C = self.clinical_raw_dim
        M = self.mri_feat_dim
        Fl = self.flag_dim
        R = self.raw_total_dim

        scaled = x[:, :, :R]
        masks = x[:, :, R:R + R]

        clinical_scaled = scaled[:, :, :C]
        clinical_mask = masks[:, :, :C]
        x_clinical = torch.cat([clinical_scaled, clinical_mask], dim=-1)

        mri_start = C
        mri_end = C + M + Fl
        mri_scaled_last = scaled[:, -1, mri_start:mri_end]
        mri_mask_last = masks[:, -1, mri_start:mri_end]
        x_mri = torch.cat([mri_scaled_last, mri_mask_last], dim=-1)

        return x_clinical, x_mri

    def forward(self, x):
        x_clinical, x_mri = self.split_clinical_mri(x)

        # --- Branche Transformer ---
        h = self.input_proj(x_clinical)
        h = h + self.pos[:, :x.size(1), :]
        h = self.encoder(h)
        h = self.tr_norm(h)
        tr_scores = self.tr_attn(h).squeeze(-1)
        tr_w = torch.softmax(tr_scores, dim=1)
        tr_ctx = torch.sum(h * tr_w.unsqueeze(-1), dim=1)          # vecteur 1

        # --- Branche BiGRU (EN PARALLELE, reçoit x_clinical directement) ---
        g, _ = self.gru(x_clinical)
        g_last = self.gru_norm(g[:, -1, :])                        # vecteur 2

        # --- Branche MRI ---
        mri_ctx = self.mri_branch(x_mri)                           # vecteur 3

        # --- Fusion finale à 3 vecteurs ---
        z = torch.cat([tr_ctx, g_last, mri_ctx], dim=1)
        logits = self.head(z)
        return logits

# ==========================================================
# 15) HORIZON DEFAULTS (nb epochs / patience finaux par horizon)
# ==========================================================
HORIZON_DEFAULTS = {
    "T2": {"max_epochs": 60, "patience": 8,  "focal_gamma": 1.5},
    "T4": {"max_epochs": 60, "patience": 10, "focal_gamma": 2.0},
    "T6": {"max_epochs": 70, "patience": 10, "focal_gamma": 2.0},
}

SEARCH_EPOCHS = 20
SEARCH_PATIENCE = 5


def plot_losses(tr, va, title):
    plt.figure(figsize=(6, 4))
    plt.plot(tr, label="train_loss")
    plt.plot(va, label="val_loss")
    plt.title(title)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.legend()
    plt.tight_layout()
    plt.show()


# ==========================================================
# 16) TRAIN ONE MODEL (Transformer//BiGRU parallèle + MRI late-fusion)
# ==========================================================
def train_levels_model(
    Xtr, ytr, Xva, yva,
    clinical_raw_dim, mri_feat_dim, flag_dim, max_len,
    d_model, nhead, num_layers, dim_feedforward,
    gru_hidden, gru_layers, head_hidden, dropout,
    lr, weight_decay, batch_size,
    max_epochs, patience,
    aug_noise, input_drop_p, focal_gamma,
    grad_clip=1.0, num_classes=4
):
    Xtr = Xtr.astype(np.float32, copy=False)
    Xva = Xva.astype(np.float32, copy=False)

    Xtr_aug = augment_noise(Xtr, scale=aug_noise)
    Xtr_aug = apply_input_dropout(Xtr_aug, p=input_drop_p, fill_value=0.0)

    class_weights = inverse_freq_weights(ytr, num_classes)
    criterion = FocalLossMulti(gamma=focal_gamma, weight=class_weights, reduction="mean")

    model = LevelsParallelLateFusionModel(
        clinical_raw_dim=clinical_raw_dim,
        mri_feat_dim=mri_feat_dim,
        flag_dim=flag_dim,
        max_len=max_len,
        d_model=d_model,
        nhead=nhead,
        num_layers=num_layers,
        dim_feedforward=dim_feedforward,
        gru_hidden=gru_hidden,
        gru_layers=gru_layers,
        head_hidden=head_hidden,
        dropout=dropout,
        num_classes=num_classes,
    ).to(device)

    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="max", factor=0.5, patience=3, min_lr=1e-5)

    sampler = make_sampler(ytr, num_classes)

    train_ds = TensorDataset(torch.tensor(Xtr_aug, dtype=torch.float32), torch.tensor(ytr, dtype=torch.long))
    val_ds = TensorDataset(torch.tensor(Xva, dtype=torch.float32), torch.tensor(yva, dtype=torch.long))

    train_dl = DataLoader(train_ds, batch_size=batch_size, sampler=sampler, num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY)
    val_dl = DataLoader(val_ds, batch_size=max(128, batch_size * 2), shuffle=False, num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY)

    best_score = -np.inf
    best_state = None
    wait = 0
    tr_losses, va_losses = [], []

    for ep in range(1, max_epochs + 1):
        model.train()
        total = 0.0
        for xb, yb in train_dl:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad(set_to_none=True)
            logits = model(xb)
            loss = criterion(logits, yb)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
            optimizer.step()
            total += loss.item()
        train_loss = total / max(len(train_dl), 1)

        model.eval()
        val_total = 0.0
        y_true_all, y_pred_all = [], []
        with torch.no_grad():
            for xb, yb in val_dl:
                xb, yb = xb.to(device), yb.to(device)
                logits = model(xb)
                loss = criterion(logits, yb)
                val_total += loss.item()
                pred = logits.argmax(dim=1)
                y_true_all.extend(yb.cpu().numpy().tolist())
                y_pred_all.extend(pred.cpu().numpy().tolist())

        val_loss = val_total / max(len(val_dl), 1)
        f1m = f1_score(y_true_all, y_pred_all, average="macro", zero_division=0)
        bacc = balanced_accuracy_score(y_true_all, y_pred_all)
        val_score = float(np.nanmean([f1m, bacc]))

        scheduler.step(val_score)
        tr_losses.append(train_loss)
        va_losses.append(val_loss)

        if ep == 1 or ep % 5 == 0:
            lr_now = optimizer.param_groups[0]["lr"]
            print(f"[Levels] ep{ep:02d} lr={lr_now:.2e} train_loss={train_loss:.5f} val_loss={val_loss:.5f} val_f1={f1m:.4f} val_bacc={bacc:.4f}")

        if val_score > best_score:
            best_score = val_score
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                print("✅ Early stopping triggered.")
                break

    if best_state is not None:
        model.load_state_dict(best_state)

    model.eval()
    return model, tr_losses, va_losses, best_score


# ==========================================================
# 17) OPTUNA OBJECTIVE (pas de fold : split train/val du seed courant)
# ==========================================================
def optuna_objective(trial, Xtr, ytr, Xva, yva, clinical_raw_dim, mri_feat_dim, flag_dim, max_len, focal_gamma_default):
    d_model = trial.suggest_categorical("d_model", [64, 96, 128])
    possible_heads = [2, 4, 8]
    valid_heads = [h for h in possible_heads if d_model % h == 0]
    nhead = trial.suggest_categorical("nhead", valid_heads)
    num_layers = trial.suggest_int("num_layers", 1, 3)
    dim_feedforward = trial.suggest_categorical("dim_feedforward", [192, 256, 320])
    gru_hidden = trial.suggest_categorical("gru_hidden", [64, 96, 128])
    gru_layers = trial.suggest_int("gru_layers", 1, 2)
    head_hidden = trial.suggest_categorical("head_hidden", [128, 160, 192])
    dropout = trial.suggest_float("dropout", 0.10, 0.35)
    lr = trial.suggest_float("lr", 2e-4, 1e-3, log=True)
    weight_decay = trial.suggest_float("weight_decay", 1e-6, 5e-4, log=True)
    aug_noise = trial.suggest_float("aug_noise", 0.0, 0.02)
    input_drop_p = trial.suggest_float("input_drop_p", 0.0, 0.05)
    focal_gamma = trial.suggest_float("focal_gamma", max(0.5, focal_gamma_default - 0.7), focal_gamma_default + 0.7)

    _, _, _, best_score = train_levels_model(
        Xtr, ytr, Xva, yva,
        clinical_raw_dim=clinical_raw_dim, mri_feat_dim=mri_feat_dim, flag_dim=flag_dim, max_len=max_len,
        d_model=d_model, nhead=nhead, num_layers=num_layers, dim_feedforward=dim_feedforward,
        gru_hidden=gru_hidden, gru_layers=gru_layers, head_hidden=head_hidden, dropout=dropout,
        lr=lr, weight_decay=weight_decay, batch_size=32,
        max_epochs=SEARCH_EPOCHS, patience=SEARCH_PATIENCE,
        aug_noise=aug_noise, input_drop_p=input_drop_p, focal_gamma=focal_gamma,
        grad_clip=GRAD_CLIP, num_classes=NUM_CLASSES
    )

    trial.report(float(best_score), step=0)
    if trial.should_prune():
        raise optuna.exceptions.TrialPruned()

    return float(best_score)


# ==========================================================
# 18) RUN ONE HORIZON (UN SEED, SANS FOLD)
# ==========================================================
def run_one_horizon_levels(X, y, pat, name="T2", n_trials=20, seed=42):
    print("\n" + "=" * 70)
    print(f"RUN PARALLEL TRANSFORMER // BiGRU + MRI LATE-FUSION (3 branches) - {name} - seed {seed}")
    print("=" * 70)

    set_seed(seed)
    defaults = HORIZON_DEFAULTS[name]

    (X_tr, y_tr, pat_tr), (X_va, y_va, pat_va), (X_te, y_te, pat_te) = split_train_val_test_patientwise(
        X, y, pat, TRAIN_RATIO, VAL_RATIO, TEST_RATIO, seed=seed
    )
    print_split_info(name, (X_tr, y_tr, pat_tr), (X_va, y_va, pat_va), (X_te, y_te, pat_te))

    X_tr_pp, med, scaler = fit_preprocess_train_only_with_mask(X_tr)
    X_va_pp = transform_with_train_params_with_mask(X_va, med, scaler)
    X_te_pp = transform_with_train_params_with_mask(X_te, med, scaler)

    max_len = X_tr_pp.shape[1]

    sampler_opt = TPESampler(seed=seed)
    pruner = MedianPruner(n_startup_trials=5)
    study = optuna.create_study(direction="maximize", sampler=sampler_opt, pruner=pruner)

    study.optimize(
        lambda trial: optuna_objective(
            trial, X_tr_pp, y_tr, X_va_pp, y_va,
            CLINICAL_RAW_DIM, MRI_FEAT_DIM, FLAG_DIM, max_len,
            defaults["focal_gamma"]
        ),
        n_trials=n_trials,
        show_progress_bar=True
    )

    best = study.best_params
    print("\n✅ BEST PARAMS:", best)

    model, tr_loss, va_loss, best_val_score = train_levels_model(
        X_tr_pp, y_tr, X_va_pp, y_va,
        clinical_raw_dim=CLINICAL_RAW_DIM, mri_feat_dim=MRI_FEAT_DIM, flag_dim=FLAG_DIM, max_len=max_len,
        d_model=best["d_model"], nhead=best["nhead"], num_layers=best["num_layers"],
        dim_feedforward=best["dim_feedforward"], gru_hidden=best["gru_hidden"], gru_layers=best["gru_layers"],
        head_hidden=best["head_hidden"], dropout=best["dropout"],
        lr=best["lr"], weight_decay=best["weight_decay"], batch_size=64,
        max_epochs=defaults["max_epochs"], patience=defaults["patience"],
        aug_noise=best["aug_noise"], input_drop_p=best["input_drop_p"], focal_gamma=best["focal_gamma"],
        grad_clip=GRAD_CLIP, num_classes=NUM_CLASSES
    )

    plot_losses(tr_loss, va_loss, f"{name} (seed {seed}) - Parallel Transformer//BiGRU + MRI late-fusion")

    # ---- TEST ----
    model.eval()
    test_ds = TensorDataset(torch.tensor(X_te_pp, dtype=torch.float32))
    test_dl = DataLoader(test_ds, batch_size=128, shuffle=False, num_workers=NUM_WORKERS, pin_memory=PIN_MEMORY)

    preds = []
    with torch.no_grad():
        for (xb,) in test_dl:
            xb = xb.to(device)
            logits = model(xb)
            preds.extend(logits.argmax(dim=1).cpu().numpy().tolist())
    preds = np.array(preds, dtype=np.int64)

    test_acc = accuracy_score(y_te, preds)
    test_precision = precision_score(y_te, preds, average="macro", zero_division=0)
    test_recall = recall_score(y_te, preds, average="macro", zero_division=0)
    test_f1 = f1_score(y_te, preds, average="macro", zero_division=0)
    test_bacc = balanced_accuracy_score(y_te, preds)
    cm = confusion_matrix(y_te, preds, labels=[0, 1, 2, 3])
    per_class_report = classification_report(
        y_te, preds, labels=[0, 1, 2, 3], target_names=CLASS_NAMES,
        output_dict=True, zero_division=0
    )

    print("\n=== TEST REPORT ===")
    print(f"Accuracy: {test_acc:.4f} | Precision: {test_precision:.4f} | Recall: {test_recall:.4f} | F1: {test_f1:.4f} | BAcc: {test_bacc:.4f}")
    print("Confusion Matrix:\n", cm)
    print(classification_report(y_te, preds, labels=[0, 1, 2, 3], target_names=CLASS_NAMES, zero_division=0))

    return {
        "name": name,
        "seed": seed,
        "accuracy": float(test_acc),
        "precision": float(test_precision),
        "recall": float(test_recall),
        "f1": float(test_f1),
        "balanced_accuracy": float(test_bacc),
        "confusion_matrix": cm.tolist(),
        "per_class": per_class_report,
        "best_params": best,
        "n_pat_train": int(len(np.unique(pat_tr))),
        "n_pat_val": int(len(np.unique(pat_va))),
        "n_pat_test": int(len(np.unique(pat_te))),
        "n_seq_train": int(X_tr.shape[0]),
        "n_seq_val": int(X_va.shape[0]),
        "n_seq_test": int(X_te.shape[0]),
        "train_loss_curve": [float(v) for v in tr_loss],
        "val_loss_curve": [float(v) for v in va_loss],
        "final_train_loss": float(tr_loss[-1]) if len(tr_loss) else float("nan"),
        "final_val_loss": float(va_loss[-1]) if len(va_loss) else float("nan"),
    }

# ==========================================================
# 19) RUN ALL WITH MULTI-SEED (SANS FOLD)
# ==========================================================
def mean_std(x):
    if len(x) == 0:
        return 0.0, 0.0
    return float(np.mean(x)), float(np.std(x))


all_results = {}

for horizon_name, (X, y, p) in {"T2": (X2, y2, p2), "T4": (X4, y4, p4), "T6": (X6, y6, p6)}.items():

    print("\n" + "=" * 80)
    print(f"RUNNING {horizon_name}")
    print("=" * 80)

    acc_scores, precision_scores, recall_scores, f1_scores, bacc_scores = [], [], [], [], []
    confusion_matrices = []
    per_class_seed_results = []
    all_seed_results = []
    train_loss_curves_seeds, val_loss_curves_seeds = [], []
    final_train_losses, final_val_losses = [], []

    for seed in SEEDS:
        print("\n" + "-" * 60)
        print(f"SEED = {seed}")
        print("-" * 60)

        res = run_one_horizon_levels(X, y, p, name=horizon_name, n_trials=N_TRIALS, seed=seed)

        print(f"\nTEST RESULTS FOR SEED = {seed}:")
        print(f"Accuracy = {res['accuracy']:.4f} | Precision = {res['precision']:.4f} | "
              f"Recall = {res['recall']:.4f} | F1 = {res['f1']:.4f} | BAcc = {res['balanced_accuracy']:.4f}")
        print("Confusion Matrix:\n", np.array(res["confusion_matrix"]))

        acc_scores.append(res["accuracy"])
        precision_scores.append(res["precision"])
        recall_scores.append(res["recall"])
        f1_scores.append(res["f1"])
        bacc_scores.append(res["balanced_accuracy"])
        confusion_matrices.append(np.array(res["confusion_matrix"]))
        per_class_seed_results.append(res["per_class"])
        all_seed_results.append(res)

        train_loss_curves_seeds.append(res["train_loss_curve"])
        val_loss_curves_seeds.append(res["val_loss_curve"])
        final_train_losses.append(res["final_train_loss"])
        final_val_losses.append(res["final_val_loss"])

    # ---- Moyennes ± std globales ----
    mean_acc, std_acc = mean_std(acc_scores)
    mean_prec, std_prec = mean_std(precision_scores)
    mean_rec, std_rec = mean_std(recall_scores)
    mean_f1, std_f1 = mean_std(f1_scores)
    mean_bacc, std_bacc = mean_std(bacc_scores)

    print("\n" + "=" * 80)
    print(f"AVERAGE RESULTS - {horizon_name}")
    print("=" * 80)
    print(f"Accuracy: {mean_acc:.4f} ± {std_acc:.4f}")
    print(f"Precision: {mean_prec:.4f} ± {std_prec:.4f}")
    print(f"Recall: {mean_rec:.4f} ± {std_rec:.4f}")
    print(f"F1-score: {mean_f1:.4f} ± {std_f1:.4f}")
    print(f"Balanced Accuracy: {mean_bacc:.4f} ± {std_bacc:.4f}")

    # ---- Per-class mean ± std ----
    per_class_summary = {}
    print("\nPer-class results (mean ± std across seeds):")
    for cls_name in CLASS_NAMES:
        cls_prec = [r[cls_name]["precision"] for r in per_class_seed_results if cls_name in r]
        cls_rec = [r[cls_name]["recall"] for r in per_class_seed_results if cls_name in r]
        cls_f1 = [r[cls_name]["f1-score"] for r in per_class_seed_results if cls_name in r]
        cls_sup = [r[cls_name]["support"] for r in per_class_seed_results if cls_name in r]

        mp, sp = mean_std(cls_prec)
        mr, sr = mean_std(cls_rec)
        mf, sf = mean_std(cls_f1)
        ms, ss = mean_std(cls_sup)

        per_class_summary[cls_name] = {
            "precision": f"{mp:.4f} ± {sp:.4f}",
            "recall": f"{mr:.4f} ± {sr:.4f}",
            "f1-score": f"{mf:.4f} ± {sf:.4f}",
            "support": f"{ms:.1f} ± {ss:.1f}",
        }
        print(f"\n{cls_name}")
        print(f"  Precision: {mp:.4f} ± {sp:.4f}")
        print(f"  Recall   : {mr:.4f} ± {sr:.4f}")
        print(f"  F1-score : {mf:.4f} ± {sf:.4f}")
        print(f"  Support  : {ms:.1f} ± {ss:.1f}")

    # ---- Matrice de confusion moyenne (arrondie) ----
    avg_cm = np.mean(np.stack(confusion_matrices), axis=0)
    std_cm = np.std(np.stack(confusion_matrices), axis=0)
    avg_cm_rounded = np.round(avg_cm, 1)

    print("\nAverage Confusion Matrix (mean across seeds, arrondie) :")
    print(avg_cm_rounded)
    print("\nStd Confusion Matrix:")
    print(np.round(std_cm, 1))

    # ---- Courbes de loss moyennes ----
    def pad_curve_to_length(curve, length):
        curve = list(curve)
        if len(curve) == 0:
            return [np.nan] * length
        if len(curve) >= length:
            return curve[:length]
        return curve + [curve[-1]] * (length - len(curve))

    def mean_std_curves(curves):
        curves = [c for c in curves if len(c) > 0]
        if len(curves) == 0:
            return np.array([]), np.array([])
        max_len_c = max(len(c) for c in curves)
        padded = np.array([pad_curve_to_length(c, max_len_c) for c in curves], dtype=float)
        return np.nanmean(padded, axis=0), np.nanstd(padded, axis=0)

    mean_train_loss_curve, std_train_loss_curve = mean_std_curves(train_loss_curves_seeds)
    mean_val_loss_curve, std_val_loss_curve = mean_std_curves(val_loss_curves_seeds)
    mean_final_train_loss, std_final_train_loss = mean_std(final_train_losses)
    mean_final_val_loss, std_final_val_loss = mean_std(final_val_losses)

    print("\nMean Train Loss / Mean Validation Loss (5 seeds):")
    print(f"  Mean Train Loss (dernière epoch) : {mean_final_train_loss:.5f} ± {std_final_train_loss:.5f}")
    print(f"  Mean Val Loss   (dernière epoch) : {mean_final_val_loss:.5f} ± {std_final_val_loss:.5f}")

    all_results[horizon_name] = {
        "Accuracy": f"{mean_acc:.4f} ± {std_acc:.4f}",
        "Precision": f"{mean_prec:.4f} ± {std_prec:.4f}",
        "Recall": f"{mean_rec:.4f} ± {std_rec:.4f}",
        "F1-score": f"{mean_f1:.4f} ± {std_f1:.4f}",
        "Balanced Accuracy": f"{mean_bacc:.4f} ± {std_bacc:.4f}",
        "Per-class": per_class_summary,
        "Mean_confusion_matrix": avg_cm_rounded.tolist(),
        "Std_confusion_matrix": np.round(std_cm, 1).tolist(),
        "Mean_Train_Loss_Final": f"{mean_final_train_loss:.5f} ± {std_final_train_loss:.5f}",
        "Mean_Val_Loss_Final": f"{mean_final_val_loss:.5f} ± {std_final_val_loss:.5f}",
        "Mean_Train_Loss_Curve": mean_train_loss_curve.tolist(),
        "Std_Train_Loss_Curve": std_train_loss_curve.tolist(),
        "Mean_Val_Loss_Curve": mean_val_loss_curve.tolist(),
        "Std_Val_Loss_Curve": std_val_loss_curve.tolist(),
        "Per_seed_results": all_seed_results,
    }


# ==========================================================
# FINAL RESULTS (résumé console)
# ==========================================================
print("\n" + "=" * 80)
print("FINAL RESULTS")
print("=" * 80)
for horizon, metrics in all_results.items():
    print("\n" + "-" * 50)
    print(horizon)
    print("-" * 50)
    for metric, value in metrics.items():
        if metric not in ("Per_seed_results", "Mean_Train_Loss_Curve", "Std_Train_Loss_Curve",
                           "Mean_Val_Loss_Curve", "Std_Val_Loss_Curve",
                           "Mean_confusion_matrix", "Std_confusion_matrix"):
            print(f"{metric}: {value}")


# ==========================================================
# 20) FIGURE COMBINEE - 3 MATRICES DE CONFUSION (T2 / T4 / T6)
# ==========================================================
HORIZON_ORDER = [h for h in ["T2", "T4", "T6"] if h in all_results]

fig_cm, axes_cm = plt.subplots(1, len(HORIZON_ORDER), figsize=(7 * len(HORIZON_ORDER), 6))
if len(HORIZON_ORDER) == 1:
    axes_cm = [axes_cm]

short_names = ["Minimal", "Mild", "Moderate", "Severe"]

for ax, horizon_name in zip(axes_cm, HORIZON_ORDER):
    avg_cm = np.array(all_results[horizon_name]["Mean_confusion_matrix"])
    im = ax.imshow(avg_cm, cmap="Blues")
    ax.set_title(f"{horizon_name} - Mean Confusion Matrix (5 seeds)")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("True")
    ax.set_xticks(range(len(short_names)))
    ax.set_xticklabels(short_names, rotation=45, ha="right")
    ax.set_yticks(range(len(short_names)))
    ax.set_yticklabels(short_names)
    for i in range(avg_cm.shape[0]):
        for j in range(avg_cm.shape[1]):
            ax.text(j, i, f"{avg_cm[i, j]:.1f}", ha="center", va="center",
                     color="white" if avg_cm[i, j] > avg_cm.max() / 2 else "black")
    fig_cm.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

fig_cm.suptitle("Matrices de confusion moyennes arrondies (mean across 5 seeds) - T2 / T4 / T6")
fig_cm.tight_layout()

cm_fig_path = OUT_DIR / "confusion_matrices_T2_T4_T6.png"
fig_cm.savefig(cm_fig_path, dpi=200, bbox_inches="tight")
plt.show()
print("✅ Figure des matrices de confusion sauvegardée :", cm_fig_path)


# ==========================================================
# 21) FIGURE COMBINEE - 3 COURBES TRAIN LOSS / VAL LOSS (T2 / T4 / T6)
# ==========================================================
fig_loss, axes_loss = plt.subplots(1, len(HORIZON_ORDER), figsize=(6 * len(HORIZON_ORDER), 4.5))
if len(HORIZON_ORDER) == 1:
    axes_loss = [axes_loss]

for ax, horizon_name in zip(axes_loss, HORIZON_ORDER):
    mtr = np.array(all_results[horizon_name]["Mean_Train_Loss_Curve"])
    mva = np.array(all_results[horizon_name]["Mean_Val_Loss_Curve"])
    str_ = np.array(all_results[horizon_name]["Std_Train_Loss_Curve"])
    sva = np.array(all_results[horizon_name]["Std_Val_Loss_Curve"])

    if len(mtr) > 0:
        epochs = np.arange(1, len(mtr) + 1)
        ax.plot(epochs, mtr, label="Mean Train Loss", color="tab:blue")
        ax.fill_between(epochs, mtr - str_, mtr + str_, color="tab:blue", alpha=0.15)
        ax.plot(epochs, mva, label="Mean Val Loss", color="tab:orange")
        ax.fill_between(epochs, mva - sva, mva + sva, color="tab:orange", alpha=0.15)

    ax.set_title(f"{horizon_name} - Train/Val Loss (mean ± std, 5 seeds)")
    ax.set_xlabel("epoch")
    ax.set_ylabel("loss")
    ax.legend()

fig_loss.suptitle("Courbes Train Loss / Validation Loss moyennes (mean across 5 seeds) - T2 / T4 / T6")
fig_loss.tight_layout()

loss_fig_path = OUT_DIR / "train_val_loss_curves_T2_T4_T6.png"
fig_loss.savefig(loss_fig_path, dpi=200, bbox_inches="tight")
plt.show()
print("✅ Figure des courbes train/val loss sauvegardée :", loss_fig_path)


# ==========================================================
# 22) TABLEAU FINAL COMPLET DE TOUTES LES METRIQUES
# ==========================================================
final_rows = []
for horizon_name in HORIZON_ORDER:
    m = all_results[horizon_name]
    row = {
        "Horizon": horizon_name,
        "Mean Accuracy ± Std": m["Accuracy"],
        "Mean Precision ± Std": m["Precision"],
        "Mean Recall ± Std": m["Recall"],
        "Mean F1 ± Std": m["F1-score"],
        "Mean Balanced Accuracy ± Std": m["Balanced Accuracy"],
        "Mean Train Loss ± Std": m["Mean_Train_Loss_Final"],
        "Mean Validation Loss ± Std": m["Mean_Val_Loss_Final"],
    }
    for cls_name in CLASS_NAMES:
        cls_metrics = m["Per-class"][cls_name]
        row[f"{cls_name} - Precision (mean ± std)"] = cls_metrics["precision"]
        row[f"{cls_name} - Recall (mean ± std)"] = cls_metrics["recall"]
        row[f"{cls_name} - F1-score (mean ± std)"] = cls_metrics["f1-score"]
        row[f"{cls_name} - Support (mean ± std)"] = cls_metrics["support"]
    final_rows.append(row)

final_metrics_df = pd.DataFrame(final_rows)

print("\n" + "=" * 80)
print("TABLEAU FINAL COMPLET DE TOUTES LES METRIQUES")
print("=" * 80)
display(final_metrics_df)


# ==========================================================
# 23) EXPORTS AUTOMATIQUES : JSON / CSV / EXCEL
# ==========================================================
results_json_path = OUT_DIR / "final_results_multi_seed_parallel_late_fusion.json"
with open(results_json_path, "w", encoding="utf-8") as f:
    json.dump(all_results, f, indent=2, ensure_ascii=False)
print("✅ Export JSON sauvegardé :", results_json_path)

rows = []
for horizon, metrics in all_results.items():
    rows.append({
        "Horizon": horizon,
        "Accuracy": metrics["Accuracy"],
        "Precision": metrics["Precision"],
        "Recall": metrics["Recall"],
        "F1-score": metrics["F1-score"],
        "Balanced Accuracy": metrics["Balanced Accuracy"],
        "Mean Train Loss": metrics["Mean_Train_Loss_Final"],
        "Mean Validation Loss": metrics["Mean_Val_Loss_Final"],
    })
summary_df = pd.DataFrame(rows)
summary_csv_path = OUT_DIR / "summary_results_multi_seed_parallel_late_fusion.csv"
summary_df.to_csv(summary_csv_path, index=False)
print("✅ Export CSV (résumé) sauvegardé :", summary_csv_path)

final_csv_path = OUT_DIR / "final_metrics_table_complete.csv"
final_metrics_df.to_csv(final_csv_path, index=False)
print("✅ Export CSV (complet, par classe) sauvegardé :", final_csv_path)

final_xlsx_path = OUT_DIR / "final_metrics_table_complete.xlsx"
try:
    with pd.ExcelWriter(final_xlsx_path, engine="openpyxl") as writer:
        final_metrics_df.to_excel(writer, sheet_name="Resume_complet", index=False)
        summary_df.to_excel(writer, sheet_name="Resume_court", index=False)

        keep_cols = [
            "seed", "accuracy", "precision", "recall", "f1", "balanced_accuracy",
            "n_pat_train", "n_pat_val", "n_pat_test",
            "n_seq_train", "n_seq_val", "n_seq_test",
            "final_train_loss", "final_val_loss"
        ]
        for horizon_name in HORIZON_ORDER:
            per_seed_df = pd.DataFrame(all_results[horizon_name]["Per_seed_results"])
            cols_present = [c for c in keep_cols if c in per_seed_df.columns]
            per_seed_df[cols_present].to_excel(writer, sheet_name=f"{horizon_name}_par_seed", index=False)
    print("✅ Export Excel sauvegardé :", final_xlsx_path)
except Exception as e:
    print("⚠️ Export Excel impossible (openpyxl manquant ?) :", e)


# ==========================================================
# 24) AFFICHAGE AUTOMATIQUE FINAL
# ==========================================================
print("\n" + "=" * 80)
print("RECAPITULATIF DES FICHIERS EXPORTES")
print("=" * 80)
print("✅ JSON   :", results_json_path)
print("✅ CSV    :", summary_csv_path)
print("✅ CSV    :", final_csv_path)
print("✅ Excel  :", final_xlsx_path)
print("✅ PNG    :", cm_fig_path)
print("✅ PNG    :", loss_fig_path)

print("\n" + "=" * 80)
print("RESUME COURT (Accuracy / Precision / Recall / F1 / Balanced Accuracy)")
print("=" * 80)
display(summary_df)

print("\n" + "=" * 80)
print("TABLEAU COMPLET (avec métriques par classe + loss)")
print("=" * 80)
display(final_metrics_df)
# Out:
# device: cpu
# [FOUND] Demographics.csv -> /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/Demographics.csv
# [FOUND] Epworth_Sleepiness_Scale.csv -> /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/Epworth_Sleepiness_Scale.csv
# [FOUND] MDS-UPDRS_Part_I.csv -> /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/MDS-UPDRS_Part_I.csv
# [FOUND] MDS-UPDRS_Part_IV.csv -> /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/MDS-UPDRS_Part_IV.csv
# [FOUND] REM_Sleep_Behavior.csv -> /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/REM_Sleep_Behavior.csv
# [FOUND] SCOPA-AUT.csv -> /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/SCOPA-AUT.csv
# [FOUND] Geriatric_Depression_Scale.csv -> /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/Geriatric_Depression_Scale.csv
# [FOUND] Participant_Status.csv -> /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/Participant_Status.csv
# [FOUND] UPDRS_PartII_PartIII.xlsx -> /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/UPDRS_PartII_PartIII.xlsx
# Merged df_seq shape: (11234, 202)
# Levels labels ready.
# Clinical feature columns: 163
# ===== POSSIBLE FILES IN /kaggle/input =====
# /kaggle/input/datasets/ANONYMIZED_USER/mri-featuress/mri_featuress.csv
# /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/MDS-UPDRS_Part_I.csv
# /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/REM_Sleep_Behavior.csv
# /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/Demographics.csv
# /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/Participant_Status.csv
# /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/MDS-UPDRS_Part_IV.csv
# /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/Epworth_Sleepiness_Scale.csv
# /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/SCOPA-AUT.csv
# /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/Geriatric_Depression_Scale.csv
# /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/UPDRS_PartII_PartIII.xlsx
# ===========================================
#
# ===== MRI CANDIDATES FOUND =====
# [0] File: /kaggle/input/datasets/ANONYMIZED_USER/mri-featuress/mri_featuress.csv
#     PATNO column: patno
#     Number of feature columns: 256
#     First 10 columns: ['PATNO', 'mri_available', 'mri_feat_000', 'mri_feat_001', 'mri_feat_002', 'mri_feat_003', 'mri_feat_004', 'mri_feat_005', 'mri_feat_006', 'mri_feat_007']
# [1] File: /kaggle/input/datasets/ANONYMIZED_USER/dataset-maladie/dataset maladie/UPDRS_PartII_PartIII.xlsx
#     PATNO column: patno
#     Number of feature columns: 85
#     First 10 columns: ['REC_ID_III', 'PATNO', 'EVENT_ID', 'PAG_NAME_III', 'INFODT', 'PDTRTMNT', 'PDSTATE', 'HRPOSTMED', 'HRDBSON', 'HRDBSOFF']
# ================================
#
# [SELECTED MRI FILE] -> /kaggle/input/datasets/ANONYMIZED_USER/mri-featuress/mri_featuress.csv
# [PATNO COLUMN] -> patno
# [NB FEATURES] -> 256
# [FINAL MRI FEATURE DIM] -> 256
# ✅ Clinical raw dim: 163
# ✅ MRI feature dim: 256
# [I 2026-07-02 09:40:03,242] A new study created in memory with name: no-name-d0f84945-2526-4d9b-abc8-acae6d6ea3ef
# ✅ T2 fused: (1258, 2, 420) unique patients: 1258
# ✅ T4 fused: (808, 4, 420) unique patients: 808
# ✅ T6 fused: (487, 6, 420) unique patients: 487
#
# ================================================================================
# RUNNING T2
# ================================================================================
#
# ------------------------------------------------------------
# SEED = 42
# ------------------------------------------------------------
#
# ======================================================================
# RUN PARALLEL TRANSFORMER // BiGRU + MRI LATE-FUSION (3 branches) - T2 - seed 42
# ======================================================================
#
# T2 SPLIT:
# Train: (880, 2, 420) patients: 880 class: (array([0, 1, 2, 3]), array([168, 669,  40,   3]))
# Val  : (189, 2, 420) patients: 189 class: (array([0, 1, 2]), array([ 40, 138,  11]))
# Test : (189, 2, 420) patients: 189 class: (array([0, 1, 2]), array([ 41, 140,   8]))
#   0%|          | 0/20 [00:00<?, ?it/s]
# [Levels] ep01 lr=4.01e-04 train_loss=0.83377 val_loss=0.40976 val_f1=0.4754 val_bacc=0.7029
# [Levels] ep05 lr=4.01e-04 train_loss=0.03755 val_loss=0.06591 val_f1=0.7058 val_bacc=0.9576
# ✅ Early stopping triggered.
# [I 2026-07-02 09:40:10,010] Trial 0 finished with value: 0.8797689422832444 and parameters: {'d_model': 96, 'nhead': 2, 'num_layers': 1, 'dim_feedforward': 192, 'gru_hidden': 96, 'gru_layers': 1, 'head_hidden': 192, 'dropout': 0.23118910790805944, 'lr': 0.00040081743753083105, 'weight_decay': 6.109683510122493e-06, 'aug_noise': 0.01223705789444759, 'input_drop_p': 0.006974693032602092, 'focal_gamma': 1.2090025079493056}. Best is trial 0 with value: 0.8797689422832444.
# [Levels] ep01 lr=4.44e-04 train_loss=0.80861 val_loss=0.36621 val_f1=0.5403 val_bacc=0.6627
# [Levels] ep05 lr=4.44e-04 train_loss=0.02085 val_loss=0.06068 val_f1=0.8085 val_bacc=0.7634
# [Levels] ep10 lr=2.22e-04 train_loss=0.00303 val_loss=0.05693 val_f1=0.8491 val_bacc=0.8074
# ✅ Early stopping triggered.
# [I 2026-07-02 09:40:15,407] Trial 1 finished with value: 0.8929700446850088 and parameters: {'d_model': 128, 'nhead': 8, 'num_layers': 1, 'dim_feedforward': 192, 'gru_hidden': 96, 'gru_layers': 1, 'head_hidden': 160, 'dropout': 0.1305095587111947, 'lr': 0.0004437555550097432, 'weight_decay': 1.2382649697023546e-06, 'aug_noise': 0.018186408041575643, 'input_drop_p': 0.012938999080000846, 'focal_gamma': 1.727531198095575}. Best is trial 1 with value: 0.8929700446850088.
# [Levels] ep01 lr=3.14e-04 train_loss=1.06024 val_loss=0.51608 val_f1=0.5670 val_bacc=0.6845
# [Levels] ep05 lr=3.14e-04 train_loss=0.06722 val_loss=0.07832 val_f1=0.8763 val_bacc=0.8490
# [Levels] ep10 lr=3.14e-04 train_loss=0.03193 val_loss=0.05612 val_f1=0.8819 val_bacc=0.8573
# [Levels] ep15 lr=1.57e-04 train_loss=0.00725 val_loss=0.06637 val_f1=0.9106 val_bacc=0.9155
# ✅ Early stopping triggered.
# [I 2026-07-02 09:40:28,517] Trial 2 finished with value: 0.9345630215195433 and parameters: {'d_model': 128, 'nhead': 4, 'num_layers': 3, 'dim_feedforward': 320, 'gru_hidden': 96, 'gru_layers': 1, 'head_hidden': 192, 'dropout': 0
. Best is trial 10 with value: 0.9747641721941516.
# [Levels] ep01 lr=7.72e-04 train_loss=1.12829 val_loss=0.74614 val_f1=0.3360 val_bacc=0.6647
# [Levels] ep05 lr=7.72e-04 train_loss=0.13791 val_loss=0.21999 val_f1=0.7569 val_bacc=0.9179
# [Levels] ep10 lr=7.72e-04 train_loss=0.04178 val_loss=0.07854 val_f1=0.8992 val_bacc=0.9326
# [Levels] ep15 lr=3.86e-04 train_loss=0.01815 val_loss=0.05400 val_f1=0.8710 val_bacc=0.8353
# ✅ Early stopping triggered.
# [I 2026-07-02 09:42:36,669] Trial 18 finished with value: 0.9496106399163469 and parameters: {'d_model': 64, 'nhead': 8, 'num_layers': 2, 'dim_feedforward': 256, 'gru_hidden': 64, 'gru_layers': 2, 'head_hidden': 128, 'dropout': 0.34736531388302877, 'lr': 0.0007719889888133691, 'weight_decay': 3.445833533202485e-06, 'aug_noise': 0.010511096231947282, 'input_drop_p': 0.019532242442591975, 'focal_gamma': 0.855379887866627}. Best is trial 10 with value: 0.9747641721941516.
# [Levels] ep01 lr=5.41e-04 train_loss=0.82230 val_loss=0.43232 val_f1=0.4603 val_bacc=0.6071
# [Levels] ep05 lr=5.41e-04 train_loss=0.06305 val_loss=0.42201 val_f1=0.5702 val_bacc=0.6517
# [Levels] ep10 lr=5.41e-04 train_loss=0.02505 val_loss=0.04932 val_f1=0.8823 val_bacc=0.8400
# ✅ Early stopping triggered.
# [I 2026-07-02 09:42:46,410] Trial 19 pruned.
#
# ✅ BEST PARAMS: {'d_model': 64, 'nhead': 8, 'num_layers': 2, 'dim_feedforward': 192, 'gru_hidden': 64, 'gru_layers': 2, 'head_hidden': 128, 'dropout': 0.2234852701150066, 'lr': 0.0009181802407551621, 'weight_decay': 3.667835329832483e-05, 'aug_noise': 0.01436760764283505, 'input_drop_p': 0.02266770947055182, 'focal_gamma': 1.3829105668507786}
# [Levels] ep01 lr=9.18e-04 train_loss=0.96156 val_loss=0.43249 val_f1=0.5802 val_bacc=0.6231
# [Levels] ep05 lr=9.18e-04 train_loss=0.08900 val_loss=0.10614 val_f1=0.8223 val_bacc=0.8984
# [Levels] ep10 lr=9.18e-04 train_loss=0.04061 val_loss=0.05698 val_f1=0.9053 val_bacc=0.9640
# [Levels] ep15 lr=4.59e-04 train_loss=0.01447 val_loss=0.04561 val_f1=0.9163 val_bacc=0.9434
# ✅ Early stopping triggered.
# [I 2026-07-02 09:42:52,401] A new study created in memory with name: no-name-72e513d7-b033-4b38-9c03-65655530b286
# === TEST REPORT ===
# Accuracy: 0.9471 | Precision: 0.8290 | Recall: 0.9369 | F1: 0.8722 | BAcc: 0.9369
# Confusion Matrix:
#  [[ 41   0   0   0]
#  [  4 131   5   0]
#  [  0   1   7   0]
#  [  0   0   0   0]]
#                        precision    recall  f1-score   support
#
#   Level0_Minimal(0-4)       0.91      1.00      0.95        41
#      Level1_Mild(5-8)       0.99      0.94      0.96       140
# Level2_Moderate(9-11)       0.58      0.88      0.70         8
#    Level3_Severe(12+)       0.00      0.00      0.00         0
#
#              accuracy                           0.95       189
#             macro avg       0.62      0.70      0.65       189
#          weighted avg       0.96      0.95      0.95       189
#
#
# TEST RESULTS FOR SEED = 42:
# Accuracy = 0.9471 | Precision = 0.8290 | Recall = 0.9369 | F1 = 0.8722 | BAcc = 0.9369
# Confusion Matrix:
#  [[ 41   0   0   0]
#  [  4 131   5   0]
#  [  0   1   7   0]
#  [  0   0   0   0]]
#
# ------------------------------------------------------------
# SEED = 43
# ------------------------------------------------------------
#
# ======================================================================
# RUN PARALLEL TRANSFORMER // BiGRU + MRI LATE-FUSION (3 branches) - T2 - seed 43
# ======================================================================
#
# T2 SPLIT:
# Train: (880, 2, 420) patients: 880 class: (array([0, 1, 2, 3]), array([170, 667,  42,   1]))
# Val  : (189, 2, 420) patients: 189 class: (array([0, 1, 2]), array([ 45, 132,  12]))
# Test : (189, 2, 420) patients: 189 class: (array([0, 1, 2, 3]), array([ 34, 148,   5,   2]))
#   0%|          | 0/20 [00:00<?, ?it/s]
# [
# ✅ Early stopping triggered.
# [I 2026-07-02 09:44:38,323] Trial 13 pruned.
# [Levels] ep01 lr=3.42e-04 train_loss=0.47927 val_loss=0.42571 val_f1=0.3439 val_bacc=0.6569
# [Levels] ep05 lr=3.42e-04 train_loss=0.01852 val_loss=0.05718 val_f1=0.8494 val_bacc=0.8865
# [Levels] ep10 lr=3.42e-04 train_loss=0.00612 val_loss=0.04070 val_f1=0.8593 val_bacc=0.8687
# ✅ Early stopping triggered.
# [I 2026-07-02 09:44:46,580] Trial 14 pruned.
# [Levels] ep01 lr=7.33e-04 train_loss=0.49227 val_loss=0.35136 val_f1=0.5144 val_bacc=0.6333
# [Levels] ep05 lr=7.33e-04 train_loss=0.03625 val_loss=0.10098 val_f1=0.8812 val_bacc=0.8687
# [Levels] ep10 lr=7.33e-04 train_loss=0.01029 val_loss=0.04324 val_f1=0.8998 val_bacc=0.8788
# ✅ Early stopping triggered.
# [I 2026-07-02 09:44:53,224] Trial 15 pruned.
# [Levels] ep01 lr=3.49e-04 train_loss=0.60560 val_loss=0.36937 val_f1=0.6023 val_bacc=0.7896
# [Levels] ep05 lr=3.49e-04 train_loss=0.02463 val_loss=0.06618 val_f1=0.8491 val_bacc=0.8662
# [Levels] ep10 lr=3.49e-04 train_loss=0.00467 val_loss=0.02611 val_f1=0.8801 val_bacc=0.8561
# ✅ Early stopping triggered.
# [I 2026-07-02 09:45:02,950] Trial 16 pruned.
# [Levels] ep01 lr=2.83e-04 train_loss=0.68867 val_loss=0.36123 val_f1=0.6210 val_bacc=0.6542
# [Levels] ep05 lr=2.83e-04 train_loss=0.06977 val_loss=0.13303 val_f1=0.8009 val_bacc=0.9167
# [Levels] ep10 lr=2.83e-04 train_loss=0.01611 val_loss=0.04837 val_f1=0.8675 val_bacc=0.8965
# [Levels] ep15 lr=2.83e-04 train_loss=0.00746 val_loss=0.03282 val_f1=0.8801 val_bacc=0.8561
# ✅ Early stopping triggered.
# [I 2026-07-02 09:45:12,025] Trial 17 pruned.
# [Levels] ep01 lr=6.20e-04 train_loss=0.38917 val_loss=0.37035 val_f1=0.4167 val_bacc=0.6490
# [Levels] ep05 lr=6.20e-04 train_loss=0.01513 val_loss=0.03107 val_f1=0.8873 val_bacc=0.9040
# ✅ Early stopping triggered.
# [I 2026-07-02 09:45:17,697] Trial 18 pruned.
# [Levels] ep01 lr=8.32e-04 train_loss=0.55835 val_loss=0.52034 val_f1=0.4592 val_bacc=0.7894
# [Levels] ep05 lr=8.32e-04 train_loss=0.03547 val_loss=0.13164 val_f1=0.8022 val_bacc=0.9199
# [Levels] ep10 lr=8.32e-04 train_loss=0.00749 val_loss=0.05585 val_f1=0.9114 val_bacc=0.9066
# [Levels] ep15 lr=8.32e-04 train_loss=0.00466 val_loss=0.03205 val_f1=0.9246 val_bacc=0.9091
# ✅ Early stopping triggered.
# [I 2026-07-02 09:45:31,950] Trial 19 pruned.
#
# ✅ BEST PARAMS: {'d_model': 64, 'nhead': 4, 'num_layers': 3, 'dim_feedforward': 256, 'gru_hidden': 64, 'gru_layers': 1, 'head_hidden': 160, 'dropout': 0.26677692733710645, 'lr': 0.0009824939534919801, 'weight_decay': 8.96505255038818e-06, 'aug_noise': 0.005123150006398082, 'input_drop_p': 0.009753125674333854, 'focal_gamma': 1.9086863755981915}
# [Levels] ep01 lr=9.82e-04 train_loss=0.50243 val_loss=0.48890 val_f1=0.4237 val_bacc=0.5987
# [Levels] ep05 lr=9.82e-04 train_loss=0.02719 val_loss=0.11973 val_f1=0.7747 val_bacc=0.9170
# [Levels] ep10 lr=9.82e-04 train_loss=0.00336 val_loss=0.04246 val_f1=0.8822 val_bacc=0.8737
# [Levels] ep15 lr=4.91e-04 train_loss=0.00238 val_loss=0.02762 val_f1=0.9171 val_bacc=0.9318
# [Levels] ep20 lr=2.46e-04 train_loss=0.00067 val_loss=0.03135 val_f1=0.9123 val_bacc=0.9293
# ✅ Early stopping triggered.
# === TEST REPORT ===
# Accuracy: 0.9206 | Precision: 0.5431 | Recall: 0.6201 | F1: 0.5610 | BAcc: 0.6201
# Confusion Matrix:
#  [[ 32   2   0   0]
#  [  1 139   8   0]
#  [  0   2   3   0]
#  [  0   0   2   0]]
#                        precision    recall  f1-score   support
#
#   Level0_Minimal(0-4)       0.97      0.94      0.96        34
#      Level1_Mild(5-8)       0.97      0.94      0.96       148
# Level2_Moderate(9-11)       0.23      0.60      0.33         5
#    Level3_Severe(12+)       0.00      0.00      0.00         2
#
#              accuracy                           0.92       189
#             macro avg       0.54      0.62      0.56       189
#          weighted avg       0.94      0.92      0.93       189
#
#
# TEST RESULTS FOR SEED = 43:
# Accuracy = 0.9206 | Precision = 0.5431 | Recall = 0.6201 | F1 = 0.5610 | BAcc = 0.6201
# Confusion Matrix:
#  [[ 32   2   0   0]
#  [  1 139   8   0]
#  [  0   2   3   0]
#  [  0   0   2   0]]
#
# ------------------------------------------------------------
# SEED = 44
# ------------------------------------------------------------
#
# ======================================================================
# RUN PARALLEL TRANSFORMER // BiGRU + MRI LATE-FUSION (3 branches) - T2 - seed 44
# ======================================================================
#
# T2 SPLIT:
# Train: (880, 2, 420) patients: 880 class: (array([0, 1, 2, 3]), array([180, 662,  35,   3]))
# Val  : (189, 2, 420) patients: 189 class: (array([0, 1, 2]), array([ 29, 145,  15]))
# Test : (189, 2, 420) patients: 189 class: (array([0, 1, 2]), array([ 40, 140,   9]))
# [I 2026-07-02 09:45:41,396] A new study created in memory with name: no-name-9e1df0ab-e195-470b-9ede-33e1a9e6309c
#   0%|          | 0/20 [00:00<?, ?it/s]
# [Levels] ep01 lr=5.66e-04 train_loss=0.87293 val_loss=0.60795 val_f1=0.2656 val_bacc=0.5632
# [Levels] ep05 lr=5.66e-04 train_loss=0.03341 val_loss=0.06122 val_f1=0.8928 val_bacc=0.8996
# [Levels] ep10 lr=5.66e-04 train_loss=0.01311 val_loss=0.05792 val_f1=0.9217 val_bacc=0.9065
# [Levels] ep15 lr=2.83e-04 train_loss=0.00161 val_loss=0.07010 val_f1=0.8988 val_bacc=0.8644
# ✅ Early stopping triggered.
# [I 2026-07-02 09:45:49,850] Trial 0 finished with value: 0.9141177617323106 and parameters: {'d_model': 64, 'nhead': 8, 'num_layers': 2, 'dim_feedforward': 320, 'gru_hidden': 64, 'gru_layers': 1, 'head_hidden': 160, 'dropout': 0
# ✅ Early stopping triggered.
# [I 2026-07-02 09:47:21,651] Trial 10 finished with value: 0.9141177617323106 and parameters: {'d_model': 128, 'nhead': 4, 'num_layers': 3, 'dim_feedforward': 192, 'gru_hidden': 96, 'gru_layers': 1, 'head_hidden': 192, 'dropout': 0.3468276548174425, 'lr': 0.0009531814159361462, 'weight_decay': 3.282225651887948e-05, 'aug_noise': 0.018910879736626814, 'input_drop_p': 0.004111761928938241, 'focal_gamma': 1.0347684128858359}. Best is trial 5 with value: 0.9203976480338912.
# [Levels] ep01 lr=6.08e-04 train_loss=0.86671 val_loss=0.38486 val_f1=0.5680 val_bacc=0.5609
# [Levels] ep05 lr=6.08e-04 train_loss=0.02732 val_loss=0.07823 val_f1=0.8907 val_bacc=0.8444
# [Levels] ep10 lr=6.08e-04 train_loss=0.01212 val_loss=0.06250 val_f1=0.8988 val_bacc=0.8644
# ✅ Early stopping triggered.
# [I 2026-07-02 09:47:27,785] Trial 11 pruned.
# [Levels] ep01 lr=6.49e-04 train_loss=0.89528 val_loss=0.29578 val_f1=0.4639 val_bacc=0.6996
# [Levels] ep05 lr=6.49e-04 train_loss=0.02458 val_loss=0.07343 val_f1=0.6395 val_bacc=0.8858
# [Levels] ep10 lr=3.24e-04 train_loss=0.00498 val_loss=0.05158 val_f1=0.8814 val_bacc=0.8506
# [Levels] ep15 lr=1.62e-04 train_loss=0.00100 val_loss=0.05538 val_f1=0.8695 val_bacc=0.8575
# ✅ Early stopping triggered.
# [I 2026-07-02 09:47:36,349] Trial 12 pruned.
# [Levels] ep01 lr=5.08e-04 train_loss=0.78501 val_loss=0.47999 val_f1=0.3335 val_bacc=0.6644
# [Levels] ep05 lr=5.08e-04 train_loss=0.06355 val_loss=0.06646 val_f1=0.6431 val_bacc=0.8498
# [Levels] ep10 lr=5.08e-04 train_loss=0.01905 val_loss=0.05463 val_f1=0.6744 val_bacc=0.9080
# [Levels] ep15 lr=5.08e-04 train_loss=0.02280 val_loss=0.03550 val_f1=0.9056 val_bacc=0.8843
# ✅ Early stopping triggered.
# [I 2026-07-02 09:47:49,360] Trial 13 finished with value: 0.9078682308330371 and parameters: {'d_model': 64, 'nhead': 8, 'num_layers': 3, 'dim_feedforward': 192, 'gru_hidden': 64, 'gru_layers': 2, 'head_hidden': 160, 'dropout': 0.3034964384674081, 'lr': 0.0005083938840722724, 'weight_decay': 4.117415233716312e-06, 'aug_noise': 0.007867450006940911, 'input_drop_p': 0.027363525231911226, 'focal_gamma': 2.1990277867460506}. Best is trial 5 with value: 0.9203976480338912.
# [Levels] ep01 lr=6.94e-04 train_loss=0.72369 val_loss=0.32599 val_f1=0.5189 val_bacc=0.7479
# [Levels] ep05 lr=6.94e-04 train_loss=0.04012 val_loss=0.07057 val_f1=0.8988 val_bacc=0.8820
# [Levels] ep10 lr=3.47e-04 train_loss=0.01425 val_loss=0.10052 val_f1=0.8082 val_bacc=0.7548
# ✅ Early stopping triggered.
# [I 2026-07-02 09:47:55,481] Trial 14 finished with value: 0.8962310209258953 and parameters: {'d_model': 64, 'nhead': 4, 'num_layers': 2, 'dim_feedforward': 320, 'gru_hidden': 64, 'gru_layers': 1, 'head_hidden': 192, 'dropout': 0.31107279158143974, 'lr': 0.0006939027201212267, 'weight_decay': 4.3556446486332304e-06, 'aug_noise': 0.012121895366362082, 'input_drop_p': 0.011250433477273876, 'focal_gamma': 1.3012059152013202}. Best is trial 5 with value: 0.9203976480338912.
# [Levels] ep01 lr=4.21e-04 train_loss=0.90077 val_loss=0.66531 val_f1=0.2414 val_bacc=0.6215
# [Levels] ep05 lr=4.21e-04 train_loss=0.05525 val_loss=0.20614 val_f1=0.6748 val_bacc=0.7494
# [Levels] ep10 lr=2.11e-04 train_loss=0.01631 val_loss=0.04667 val_f1=0.8951 val_bacc=0.8996
# [Levels] ep15 lr=2.11e-04 train_loss=0.00925 val_loss=0.04436 val_f1=0.9115 val_bacc=0.9042
# [Levels] ep20 lr=1.05e-04 train_loss=0.00653 val_loss=0.05617 val_f1=0.8605 val_bacc=0.8375
# [I 2026-07-02 09:48:08,665] Trial 15 finished with value: 0.9203976480338912 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 2, 'dim_feedforward': 192, 'gru_hidden': 96, 'gru_layers': 2, 'head_hidden': 128, 'dropout': 0.26729001834832533, 'lr': 0.0004213846907968606, 'weight_decay': 1.6436048196264745e-05, 'aug_noise': 0.00035525991961637797, 'input_drop_p': 0.012195067289123205, 'focal_gamma': 1.794823363166936}. Best is trial 5 with value: 0.9203976480338912.
# [Levels] ep01 lr=3.92e-04 train_loss=0.93182 val_loss=0.43041 val_f1=0.2878 val_bacc=0.4851
# [Levels] ep05 lr=3.92e-04 train_loss=0.05939 val_loss=0.05849 val_f1=0.6768 val_bacc=0.9272
# [Levels] ep10 lr=1.96e-04 train_loss=0.02742 val_loss=0.06326 val_f1=0.6409 val_bacc=0.8238
# ✅ Early stopping triggered.
# [I 2026-07-02 09:48:17,156] Trial 16 finished with value: 0.9152735636855418 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 3, 'dim_feedforward': 192, 'gru_hidden': 96, 'gru_layers': 2, 'head_hidden': 128, 'dropout': 0.26756868409442874, 'lr': 0.00039244865202867464, 'weight_decay': 3.164274390635581e-05, 'aug_noise': 0.0007787179915566423, 'input_drop_p': 0.0192331290107481, 'focal_gamma': 1.8257418375976058}. Best is trial 5 with value: 0.9203976480338912.
# [Levels] ep01 lr=3.77e-04 train_loss=0.76645 val_loss=0.36832 val_f1=0.4567 val_bacc=0.6536
# [Levels] ep05 lr=3.77e-04 train_loss=0.04751 val_loss=0.07309 val_f1=0.8887 val_bacc=0.9326
# [Levels] ep10 lr=1.88e-04 train_loss=0.01681 val_loss=0.05189 val_f1=0.8793 val_bacc=0.8682
# ✅ Early stopping triggered.
# [I 2026-07-02 09:48:24,461] Trial 17 finished with value: 0.9106102777416056 and parameters: {'d_model': 128, 'nhead': 2, 'num_layers': 2, 'dim_feedforward': 192, 'gru_hidden': 96, 'gru_layers': 2, 'head_hidden': 128, 'dropout': 0.20586803614162752, 'lr': 0.0003766220652818458, 'weight_decay': 1.4725224701689381e-05, 'aug_noise': 0.019895051604901466, 'input_drop_p': 0.02631971368745433, 'focal_gamma': 1.707901525348117}. Best is trial 5 with value: 0.9203976480338912.
# [Levels] ep01 lr=7.94e-04 train_loss=0.60342 val_loss=0.34879 val_f1=0.4487 val_bacc=0.6805
# [Levels] ep05 lr=7.94e-04 train_loss=0.03886 val_loss=0.04185 val_f1=0.8637 val_bacc=0.8536
# ...
# [Levels] ep05 lr=3.33e-04 train_loss=0.14582 val_loss=0.23013 val_f1=0.4152 val_bacc=0.5745
# [Levels] ep10 lr=3.33e-04 train_loss=0.03001 val_loss=0.16286 val_f1=0.6608 val_bacc=0.8775
# [Levels] ep15 lr=3.33e-04 train_loss=0.01219 val_loss=0.08970 val_f1=0.9036 val_bacc=0.9036
# [Levels] ep20 lr=1.67e-04 train_loss=0.00498 val_loss=0.09778 val_f1=0.8763 val_bacc=0.8333
# ✅ Early stopping triggered.
# [I 2026-07-02 10:19:13,868] Trial 19 finished with value: 0.9035947712418301 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 1, 'dim_feedforward': 192, 'gru_hidden': 96, 'gru_layers': 1, 'head_hidden': 192, 'dropout': 0.24217291944967503, 'lr': 0.0003331127185283258, 'weight_decay': 0.00024991270024161694, 'aug_noise': 7.47677235132492e-05, 'input_drop_p': 0.012832017661662658, 'focal_gamma': 1.816354780490617}. Best is trial 9 with value: 0.9168776572117521.
#
# ✅ BEST PARAMS: {'d_model': 128, 'nhead': 8, 'num_layers': 1, 'dim_feedforward': 256, 'gru_hidden': 128, 'gru_layers': 1, 'head_hidden': 128, 'dropout': 0.28180032796870746, 'lr': 0.0002570095666078652, 'weight_decay': 1.8657501146282016e-05, 'aug_noise': 0.0012417627469321802, 'input_drop_p': 0.010532296987853558, 'focal_gamma': 2.2745331898298566}
# [Levels] ep01 lr=2.57e-04 train_loss=1.22695 val_loss=0.83390 val_f1=0.0273 val_bacc=0.0196
# [Levels] ep05 lr=2.57e-04 train_loss=0.38166 val_loss=0.55217 val_f1=0.3164 val_bacc=0.5636
# [Levels] ep10 lr=2.57e-04 train_loss=0.10990 val_loss=0.23589 val_f1=0.5143 val_bacc=0.6513
# [Levels] ep15 lr=2.57e-04 train_loss=0.05377 val_loss=0.21239 val_f1=0.5601 val_bacc=0.7799
# [Levels] ep20 lr=2.57e-04 train_loss=0.02319 val_loss=0.20547 val_f1=0.5841 val_bacc=0.8448
# [Levels] ep25 lr=6.43e-05 train_loss=0.00995 val_loss=0.13957 val_f1=0.6056 val_bacc=0.8126
# ✅ Early stopping triggered.
# === TEST REPORT ===
# Accuracy: 0.9054 | Precision: 0.7318 | Recall: 0.8183 | F1: 0.7525 | BAcc: 0.8183
# Confusion Matrix:
#  [[13  1  0  0]
#  [ 0 51  2  1]
#  [ 0  3  2  0]
#  [ 0  0  0  1]]
#                        precision    recall  f1-score   support
#
#   Level0_Minimal(0-4)       1.00      0.93      0.96        14
#      Level1_Mild(5-8)       0.93      0.94      0.94        54
# Level2_Moderate(9-11)       0.50      0.40      0.44         5
#    Level3_Severe(12+)       0.50      1.00      0.67         1
#
#              accuracy                           0.91        74
#             macro avg       0.73      0.82      0.75        74
#          weighted avg       0.91      0.91      0.90        74
#
#
# TEST RESULTS FOR SEED = 46:
# Accuracy = 0.9054 | Precision = 0.7318 | Recall = 0.8183 | F1 = 0.7525 | BAcc = 0.8183
# Confusion Matrix:
#  [[13  1  0  0]
#  [ 0 51  2  1]
#  [ 0  3  2  0]
#  [ 0  0  0  1]]
#
# ================================================================================
# AVERAGE RESULTS - T6
# ================================================================================
# Accuracy: 0.8784 ± 0.0392
# Precision: 0.6035 ± 0.0857
# Recall: 0.6084 ± 0.1230
# F1-score: 0.5993 ± 0.0974
# Balanced Accuracy: 0.6774 ± 0.1066
#
# Per-class results (mean ± std across seeds):
#
# Level0_Minimal(0-4)
#   Precision: 0.9306 ± 0.0679
#   Recall   : 0.9621 ± 0.0313
#   F1-score : 0.9443 ± 0.0354
#   Support  : 16.6 ± 1.7
#
# Level1_Mild(5-8)
#   Precision: 0.9360 ± 0.0059
#   Recall   : 0.9105 ± 0.0530
#   F1-score : 0.9223 ± 0.0283
#   Support  : 51.4 ± 2.9
#
# Level2_Moderate(9-11)
#   Precision: 0.4476 ± 0.2320
#   Recall   : 0.3610 ± 0.1981
#   F1-score : 0.3975 ± 0.2101
#   Support  : 5.0 ± 1.4
#
# Level3_Severe(12+)
#   Precision: 0.1000 ± 0.2000
#   Recall   : 0.2000 ± 0.4000
#   F1-score : 0.1333 ± 0.2667
#   Support  : 1.0 ± 0.9
#
# Average Confusion Matrix (mean across seeds, arrondie) :
# [[16.   0.6  0.   0. ]
#  [ 1.4 46.8  2.6  0.6]
#  [ 0.   2.4  2.   0.6]
#  [ 0.   0.2  0.6  0.2]]
#
# Std Confusion Matrix:
# [[2.  0.5 0.  0. ]
#  [1.5 3.8 2.7 0.5]
#  [0.  0.5 1.3 0.8]
#  [0.  0.4 0.8 0.4]]
#
# Mean Train Loss / Mean Validation Loss (5 seeds):
#   Mean Train Loss (dernière epoch) : 0.00628 ± 0.00313
#   Mean Val Loss   (dernière epoch) : 0.15066 ± 0.07312
#
# ================================================================================
# FINAL RESULTS
# ================================================================================
#
# --------------------------------------------------
# T2
# --------------------------------------------------
# Accuracy: 0.9397 ± 0.0166
# Precision: 0.7874 ± 0.1298
# Recall: 0.8729 ± 0.1280
# F1-score: 0.8131 ± 0.1304
# Balanced Accuracy: 0.8729 ± 0.1280
# Per-class: {'Level0_Minimal(0-4)': {'precision': '0.9762 ± 0.0346', 'recall': '0.9813 ± 0.0241', 'f1-score': '0.9782 ± 0.0205', 'support': '34.6 ± 5.2'}, 'Level1_Mild(5-8)': {'precision': '0.9845 ± 0.0102', 'recall': '0.9385 ± 0.0261', 'f1-score': '0.9606 ± 0.0107', 'support': '143.6 ± 3.7'}, 'Level2_Moderate(9-11)': {'precision': '0.5103 ± 0.1941', 'recall': '0.8228 ± 0.1367', 'f1-score': '0.6128 ± 0.1695', 'support': '10.4 ± 4.4'}, 'Level3_Severe(12+)': {'precision': '0.0000 ± 0.0000', 'recall': '0.0000 ± 0.0000', 'f1-score': '0.0000 ± 0.0000', 'support': '0.4 ± 0.8'}}
# Mean_Train_Loss_Final: 0.00911 ± 0.00561
# Mean_Val_Loss_Final: 0.05722 ± 0.02846
#
# --------------------------------------------------
# T4
# --------------------------------------------------
# Accuracy: 0.9574 ± 0.0109
# Precision: 0.7671 ± 0.1153
# Recall: 0.8022 ± 0.0826
# F1-score: 0.7798 ± 0.1013
# Balanced Accuracy: 0.8022 ± 0.0826
# Per-class: {'Level0_Minimal(0-4)': {'precision': '1.0000 ± 0.0000', 'recall': '1.0000 ± 0.0000', 'f1-score': '1.0000 ± 0.0000', 'support': '19.6 ± 2.2'}, 'Level1_Mild(5-8)': {'precision': '0.9831 ± 0.0049', 'recall': '0.9663 ± 0.0142', 'f1-score': '0.9745 ± 0.0066', 'support': '95.6 ± 2.5'}, 'Level2_Moderate(9-11)': {'precision': '0.5739 ± 0.1499', 'recall': '0.7226 ± 0.1372', 'f1-score': '0.6307 ± 0.1172', 'support': '6.4 ± 1.4'}, 'Level3_Severe(12+)': {'precision': '0.0000 ± 0.0000', 'recall': '0.0000 ± 0.0000', 'f1-score': '0.0000 ± 0.0000', 'support': '0.4 ± 0.5'}}
# Mean_Train_Loss_Final: 0.00351 ± 0.00273
# Mean_Val_Loss_Final: 0.08385 ± 0.07470
#
# --------------------------------------------------
# T6
# --------------------------------------------------
# Accuracy: 0.8784 ± 0.0392
# Precision: 0.6035 ± 0.0857
# Recall: 0.6084 ± 0.1230
# F1-score: 0.5993 ± 0.0974
# Balanced Accuracy: 0.6774 ± 0.1066
# Per-class: {'Level0_Minimal(0-4)': {'precision': '0.9306 ± 0.0679', 'recall': '0.9621 ± 0.0313', 'f1-score': '0.9443 ± 0.0354', 'support': '16.6 ± 1.7'}, 'Level1_Mild(5-8)': {'precision': '0.9360 ± 0.0059', 'recall': '0.9105 ± 0.0530', 'f1-score': '0.9223 ± 0.0283', 'support': '51.4 ± 2.9'}, 'Level2_Moderate(9-11)': {'precision': '0.4476 ± 0.2320', 'recall': '0.3610 ± 0.1981', 'f1-score': '0.3975 ± 0.2101', 'support': '5.0 ± 1.4'}, 'Level3_Severe(12+)': {'precision': '0.1000 ± 0.2000', 'recall': '0.2000 ± 0.4000', 'f1-score': '0.1333 ± 0.2667', 'support': '1.0 ± 0.9'}}
# Mean_Train_Loss_Final: 0.00628 ± 0.00313
# Mean_Val_Loss_Final: 0.15066 ± 0.07312
# ✅ Figure des matrices de confusion sauvegardée : /kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold/confusion_matrices_T2_T4_T6.png
# ✅ Figure des courbes train/val loss sauvegardée : /kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold/train_val_loss_curves_T2_T4_T6.png
#
# ================================================================================
# TABLEAU FINAL COMPLET DE TOUTES LES METRIQUES
# ================================================================================
#   Horizon Mean Accuracy ± Std Mean Precision ± Std Mean Recall ± Std  \
# 0      T2     0.9397 ± 0.0166      0.7874 ± 0.1298   0.8729 ± 0.1280
# 1      T4     0.9574 ± 0.0109      0.7671 ± 0.1153   0.8022 ± 0.0826
# 2      T6     0.8784 ± 0.0392      0.6035 ± 0.0857   0.6084 ± 0.1230
#
#      Mean F1 ± Std Mean Balanced Accuracy ± Std Mean Train Loss ± Std  \
# 0  0.8131 ± 0.1304              0.8729 ± 0.1280     0.00911 ± 0.00561
# 1  0.7798 ± 0.1013              0.8022 ± 0.0826     0.00351 ± 0.00273
# 2  0.5993 ± 0.0974              0.6774 ± 0.1066     0.00628 ± 0.00313
#
#   Mean Validation Loss ± Std Level0_Minimal(0-4) - Precision (mean ± std)  \
# 0          0.05722 ± 0.02846                              0.9762 ± 0.0346
# 1          0.08385 ± 0.07470                              1.0000 ± 0.0000
# 2          0.15066 ± 0.07312                              0.9306 ± 0.0679
#
#   Level0_Minimal(0-4) - Recall (mean ± std)  ...  \
# 0                           0.9813 ± 0.0241  ...
# 1                           1.0000 ± 0.0000  ...
# 2                           0.9621 ± 0.0313  ...
#
#   Level1_Mild(5-8) - F1-score (mean ± std)  \
# 0                          0.9606 ± 0.0107
# 1                          0.9745 ± 0.0066
# 2                          0.9223 ± 0.0283
#
#   Level1_Mild(5-8) - Support (mean ± std)  \
# 0                             143.6 ± 3.7
# 1                              95.6 ± 2.5
# 2                              51.4 ± 2.9
#
#   Level2_Moderate(9-11) - Precision (mean ± std)  \
# 0                                0.5103 ± 0.1941
# 1                                0.5739 ± 0.1499
# 2                                0.4476 ± 0.2320
#
#   Level2_Moderate(9-11) - Recall (mean ± std)  \
# 0                             0.8228 ± 0.1367
# 1                             0.7226 ± 0.1372
# 2                             0.3610 ± 0.1981
#
#   Level2_Moderate(9-11) - F1-score (mean ± std)  \
# 0                               0.6128 ± 0.1695
# 1                               0.6307 ± 0.1172
# 2                               0.3975 ± 0.2101
#
#   Level2_Moderate(9-11) - Support (mean ± std)  \
# 0                                   10.4 ± 4.4
# 1                                    6.4 ± 1.4
# 2                                    5.0 ± 1.4
#
#   Level3_Severe(12+) - Precision (mean ± std)  \
# 0                             0.0000 ± 0.0000
# 1                             0.0000 ± 0.0000
# 2                             0.1000 ± 0.2000
#
#   Level3_Severe(12+) - Recall (mean ± std)  \
# 0                          0.0000 ± 0.0000
# 1                          0.0000 ± 0.0000
# 2                          0.2000 ± 0.4000
#
#   Level3_Severe(12+) - F1-score (mean ± std)  \
# 0                            0.0000 ± 0.0000
# 1                            0.0000 ± 0.0000
# 2                            0.1333 ± 0.2667
#
#   Level3_Severe(12+) - Support (mean ± std)
# 0                                 0.4 ± 0.8
# 1                                 0.4 ± 0.5
# 2                                 1.0 ± 0.9
#
# [3 rows x 24 columns]
# ✅ Export JSON sauvegardé : /kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold/final_results_multi_seed_parallel_late_fusion.json
# ✅ Export CSV (résumé) sauvegardé : /kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold/summary_results_multi_seed_parallel_late_fusion.csv
# ✅ Export CSV (complet, par classe) sauvegardé : /kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold/final_metrics_table_complete.csv
# ✅ Export Excel sauvegardé : /kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold/final_metrics_table_complete.xlsx
#
# ================================================================================
# RECAPITULATIF DES FICHIERS EXPORTES
# ================================================================================
# ✅ JSON   : /kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold/final_results_multi_seed_parallel_late_fusion.json
# ✅ CSV    : /kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold/summary_results_multi_seed_parallel_late_fusion.csv
# ✅ CSV    : /kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold/final_metrics_table_complete.csv
# ✅ Excel  : /kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold/final_metrics_table_complete.xlsx
# ✅ PNG    : /kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold/confusion_matrices_T2_T4_T6.png
# ✅ PNG    : /kaggle/working/levels_late_fusion_parallel_multi_seed_no_fold/train_val_loss_curves_T2_T4_T6.png
#
# ================================================================================
# RESUME COURT (Accuracy / Precision / Recall / F1 / Balanced Accuracy)
# ================================================================================
#   Horizon         Accuracy        Precision           Recall         F1-score  \
# 0      T2  0.9397 ± 0.0166  0.7874 ± 0.1298  0.8729 ± 0.1280  0.8131 ± 0.1304
# 1      T4  0.9574 ± 0.0109  0.7671 ± 0.1153  0.8022 ± 0.0826  0.7798 ± 0.1013
# 2      T6  0.8784 ± 0.0392  0.6035 ± 0.0857  0.6084 ± 0.1230  0.5993 ± 0.0974
#
#   Balanced Accuracy    Mean Train Loss Mean Validation Loss
# 0   0.8729 ± 0.1280  0.00911 ± 0.00561    0.05722 ± 0.02846
# 1   0.8022 ± 0.0826  0.00351 ± 0.00273    0.08385 ± 0.07470
# 2   0.6774 ± 0.1066  0.00628 ± 0.00313    0.15066 ± 0.07312
# ================================================================================
# TABLEAU COMPLET (avec métriques par classe + loss)
# ================================================================================
#   Horizon Mean Accuracy ± Std Mean Precision ± Std Mean Recall ± Std  \
# 0      T2     0.9397 ± 0.0166      0.7874 ± 0.1298   0.8729 ± 0.1280
# 1      T4     0.9574 ± 0.0109      0.7671 ± 0.1153   0.8022 ± 0.0826
# 2      T6     0.8784 ± 0.0392      0.6035 ± 0.0857   0.6084 ± 0.1230
#
#      Mean F1 ± Std Mean Balanced Accuracy ± Std Mean Train Loss ± Std  \
# 0  0.8131 ± 0.1304              0.8729 ± 0.1280     0.00911 ± 0.00561
# 1  0.7798 ± 0.1013              0.8022 ± 0.0826     0.00351 ± 0.00273
# 2  0.5993 ± 0.0974              0.6774 ± 0.1066     0.00628 ± 0.00313
#
#   Mean Validation Loss ± Std Level0_Minimal(0-4) - Precision (mean ± std)  \
# 0          0.05722 ± 0.02846                              0.9762 ± 0.0346
# 1          0.08385 ± 0.07470                              1.0000 ± 0.0000
# 2          0.15066 ± 0.07312                              0.9306 ± 0.0679
#
#   Level0_Minimal(0-4) - Recall (mean ± std)  ...  \
# 0                           0.9813 ± 0.0241  ...
# 1                           1.0000 ± 0.0000  ...
# 2                           0.9621 ± 0.0313  ...
#
#   Level1_Mild(5-8) - F1-score (mean ± std)  \
# 0                          0.9606 ± 0.0107
# 1                          0.9745 ± 0.0066
# 2                          0.9223 ± 0.0283
#
#   Level1_Mild(5-8) - Support (mean ± std)  \
# 0                             143.6 ± 3.7
# 1                              95.6 ± 2.5
# 2                              51.4 ± 2.9
#
#   Level2_Moderate(9-11) - Precision (mean ± std)  \
# 0                                0.5103 ± 0.1941
# 1                                0.5739 ± 0.1499
# 2                                0.4476 ± 0.2320
#
#   Level2_Moderate(9-11) - Recall (mean ± std)  \
# 0                             0.8228 ± 0.1367
# 1                             0.7226 ± 0.1372
# 2                             0.3610 ± 0.1981
#
#   Level2_Moderate(9-11) - F1-score (mean ± std)  \
# 0                               0.6128 ± 0.1695
# 1                               0.6307 ± 0.1172
# 2                               0.3975 ± 0.2101
#
#   Level2_Moderate(9-11) - Support (mean ± std)  \
# 0                                   10.4 ± 4.4
# 1                                    6.4 ± 1.4
# 2                                    5.0 ± 1.4
#
#   Level3_Severe(12+) - Precision (mean ± std)  \
# 0                             0.0000 ± 0.0000
# 1                             0.0000 ± 0.0000
# 2                             0.1000 ± 0.2000
#
#   Level3_Severe(12+) - Recall (mean ± std)  \
# 0                          0.0000 ± 0.0000
# 1                          0.0000 ± 0.0000
# 2                          0.2000 ± 0.4000
#
#   Level3_Severe(12+) - F1-score (mean ± std)  \
# 0                            0.0000 ± 0.0000
# 1                            0.0000 ± 0.0000
# 2                            0.1333 ± 0.2667
#
#   Level3_Severe(12+) - Support (mean ± std)
# 0                                 0.4 ± 0.8
# 1                                 0.4 ± 0.5
# 2                                 1.0 ± 0.9
#
# [3 rows x 24 columns]
